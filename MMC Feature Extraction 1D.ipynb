# %% [markdown]
# ## 1. Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
'''------Reading files------'''
import os

'''------Audio preprocessing------'''
from pydub import AudioSegment

'''------Manipulating data------'''
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder # Numerical encoding

'''------Loading the audio------'''
import librosa
import librosa.display
from IPython import display
'''------Deep learning model------'''
import tensorflow as tf
# Out:
# 2023-06-19 10:34:24.141130: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. Audio Data Preprocessing
# ### 2.1 Reading the audio files

# %%
count = 0
fileDirMER = 'Dataset/MER'
dataset = os.listdir(fileDirMER)
filewithdir = []
file = []

for mooddir in dataset:
    if(not r'.' in mooddir):
        moodDirName = os.path.join(fileDirMER,mooddir)
        mooddir=np.array(os.listdir(moodDirName))
        for audio in mooddir:
            if(audio[-3:]=='mp3'):
                count+=1
                fn=os.path.join(moodDirName,audio)
                filewithdir.append(fn)
                file.append(os.path.basename(fn))
                print(str(count),fn)
# Out:
# 1 Dataset/MER/Q1/MT0009845271.mp3
# 2 Dataset/MER/Q1/MT0012742379.mp3
# 3 Dataset/MER/Q1/MT0009188643.mp3
# 4 Dataset/MER/Q1/MT0011560587.mp3
# 5 Dataset/MER/Q1/MT0001605268.mp3
# 6 Dataset/MER/Q1/MT0005832516.mp3
# 7 Dataset/MER/Q1/MT0007147603.mp3
# 8 Dataset/MER/Q1/MT0033940994.mp3
# 9 Dataset/MER/Q1/MT0014576739.mp3
# 10 Dataset/MER/Q1/MT0000392975.mp3
# 11 Dataset/MER/Q1/MT0013389935.mp3
# 12 Dataset/MER/Q1/MT0004037272.mp3
# 13 Dataset/MER/Q1/MT0011916674.mp3
# 14 Dataset/MER/Q1/MT0002033629.mp3
# 15 Dataset/MER/Q1/MT0005737276.mp3
# 16 Dataset/MER/Q1/MT0002119439.mp3
# 17 Dataset/MER/Q1/MT0003044417.mp3
# 18 Dataset/MER/Q1/MT0003788939.mp3
# 19 Dataset/MER/Q1/MT0015742096.mp3
# 20 Dataset/MER/Q1/MT0008276791.mp3
# 21 Dataset/MER/Q1/MT0027159893.mp3
# 22 Dataset/MER/Q1/MT0011957429.mp3
# 23 Dataset/MER/Q1/MT0008575372.mp3
# 24 Dataset/MER/Q1/MT0003170370.mp3
# 25 Dataset/MER/Q1/MT0002222957.mp3
# 26 Dataset/MER/Q1/MT0001757676.mp3
# 27 Dataset/MER/Q1/MT0002262181.mp3
# 28 Dataset/MER/Q1/MT0003669917.mp3
# 29 Dataset/MER/Q1/MT0010487769.mp3
# 30 Dataset/MER/Q1/MT0026753600.mp3
# 31 Dataset/MER/Q1/MT0026753827.mp3
# 32 Dataset/MER/Q1/MT0008675527.mp3
# 33 Dataset/MER/Q1/MT0012846850.mp3
# 34 Dataset/MER/Q1/MT0008222676.mp3
# 35 Dataset/MER/Q1/MT0005003824.mp3
# 36 Dataset/MER/Q1/MT0004339430.mp3
# 37 Dataset/MER/Q1/MT0001703346.mp3
# 38 Dataset/MER/Q1/MT0036368550.mp3
# 39 Dataset/MER/Q1/MT0031544440.mp3
# 40 Dataset/MER/Q1/MT0027035970.mp3
# 41 Dataset/MER/Q1/MT0003286463.mp3
# 891 Dataset/MER/Q3/MT0031693432.mp3
# 892 Dataset/MER/Q3/MT0002986568.mp3
# 893 Dataset/MER/Q3/MT0005115042.mp3
# 894 Dataset/MER/Q3/MT0008979040.mp3
# 895 Dataset/MER/Q3/MT0001844620.mp3
# 896 Dataset/MER/Q3/MT0010804974.mp3
# 897 Dataset/MER/Q3/MT0000796526.mp3
# 898 Dataset/MER/Q3/MT0015664499.mp3
# 899 Dataset/MER/Q3/MT0012292188.mp3
# 900 Dataset/MER/Q3/MT0004342301.mp3

# %%
count_extra = 0
fileDirMER_extra = 'Dataset/MER_Extra'
dataset_extra = os.listdir(fileDirMER_extra)
filewithdir_extra = []
file_extra = []

for mooddir in dataset_extra:
    if(not r'.' in mooddir):
        moodDirName = os.path.join(fileDirMER_extra,mooddir)
        mooddir=np.array(os.listdir(moodDirName))
        for audio in mooddir:
            if(audio[-3:]=='mp3'):
                count_extra+=1
                fn=os.path.join(moodDirName,audio)
                filewithdir_extra.append(fn)
                file_extra.append(os.path.basename(fn))
                print(str(count_extra),fn)
# Out:
# 1 Dataset/MER_Extra/happy/ovalar_gurup_yol.mp3
# 2 Dataset/MER_Extra/happy/cekirge_oguz_yilmaz.mp3
# 3 Dataset/MER_Extra/happy/baran_bayraktar_gol.mp3
# 4 Dataset/MER_Extra/happy/bu_gece_uyumamisan.mp3
# 5 Dataset/MER_Extra/happy/kim_arar_nilufer.mp3
# 6 Dataset/MER_Extra/happy/heycan_serdar_ortac.mp3
# 7 Dataset/MER_Extra/happy/su_gelen_atlimidir.mp3
# 8 Dataset/MER_Extra/happy/yuru_dilber_yuru_fasil.mp3
# 9 Dataset/MER_Extra/happy/arzu_kus_adana_kopru_basi.mp3
# 10 Dataset/MER_Extra/happy/evlere_senlik_sinan_ozen.mp3
# 11 Dataset/MER_Extra/happy/ayse_ozyilmazel_pardon.mp3
# 12 Dataset/MER_Extra/happy/yangin_olur_biz_yangina_gideriz_fasli_beyoglu.mp3
# 13 Dataset/MER_Extra/happy/uskudara_gideriken.mp3
# 14 Dataset/MER_Extra/happy/cay_elinden_oteye_sevval_sam.mp3
# 15 Dataset/MER_Extra/happy/mustafa_sandal_aya_benzer.mp3
# 16 Dataset/MER_Extra/happy/gul_doktum_yollarina_tarkan.mp3
# 17 Dataset/MER_Extra/happy/sevinc_sarivea_yandirgin_kalbimi_aman.mp3
# 18 Dataset/MER_Extra/happy/sigaramin_duman_meski_fasil.mp3
# 19 Dataset/MER_Extra/happy/mektebin_bacalari_yahya_cekirge.mp3
# 20 Dataset/MER_Extra/happy/siverek_asmasiyam_ibrahim_tatlises.mp3
# 21 Dataset/MER_Extra/happy/cakmak_cakmaga_geldik_cesitli_sanatci.mp3
# 22 Dataset/MER_Extra/happy/kalenin_bedenleri_zara.mp3
# 23 Dataset/MER_Extra/happy/beyoglunda_gezersin.mp3
# 24 Dataset/MER_Extra/happy/erkilet_guzeli_meski_fasil.mp3
# 25 Dataset/MER_Extra/happy/aynali_koruk_zara.mp3
# 26 Dataset/MER_Extra/happy/kocari_kazim_koyuncu.mp3
# 27 Dataset/MER_Extra/happy/zeytin_yapragi_yesil_zara.mp3
# 28 Dataset/MER_Extra/happy/ayva_cicek_acmis_fasli_beyoglu.mp3
# 29 Dataset/MER_Extra/happy/sendeki_kaslar_suzan_kardes.mp3
# 30 Dataset/MER_Extra/happy/bag_gel_bostana_gel_kubat.mp3
# 31 Dataset/MER_Extra/happy/ah_nerede_vah_nerede_fusun_onal.mp3
# 32 Dataset/MER_Extra/happy/yar_saclarin_lule_lule_nesrin_sipahi.mp3
# 33 Dataset/MER_Extra/happy/diyar_bakir_guzel_baglar_yahya_cekirge.mp3
# 34 Dataset/MER_Extra/happy/kadifeden_kesesi_fasli_beyoglu.mp3
# 35 Dataset/MER_Extra/happy/mardin_kapisindan_atyalyamadm_kazanc_bedih.mp3
# 36 Dataset/MER_Extra/happy/son_verdim_kalbimin_issine_seyyal_taner.mp3
# 37 Dataset/MER_Extra/happy/darildinmi_cicim_bana_fasli_beyoglu.mp3
# 38 Dataset/MER_Extra/happy/karabiberim_serdar_ortac.mp3
# 39 Dataset/MER_Extra/happy/gulum_benim_muazzez_ersoy.mp3
# 40 Dataset/MER_Extra/happy/gozleri_aska_gulen_funda_arar.mp3
# 41 Dataset/MER_Extra/happy/yola_ciktim_mardine_berdan.mp3
# 42 Dataset/MER_Extra/happy/antebin_kalesine_ibrahim_tatlises.mp3
# 43 Dataset/MER_Extra/happy/hadi_gari_sende_gel.mp3
# 44 Dataset/MER_Extra/happy/yuksek_yuksek_tepelere.mp3
# 45 Dataset/MER_Extra/happy/diyarbakir_lorke_halayi.mp3
# 46 Dataset/MER_Extra/happy/askimiz_bitecek_cansu_koc.mp3
# 47 Dataset/MER_Extra/happy/altun_kardesler_erik_dali.mp3
# 48 Dataset/MER_Extra/happy/aya_benzer_mustafa_sandal.mp3
# 49 Dataset/MER_Extra/happy/davullu_zurnali_oyun_havasi.mp3
# 50 Dataset/MER_Extra/happy/kondurama_kum_doldu_cesitli_sanatci.mp3
# 51 Dataset/MER_Extra/happy/murat-kursun-erik-dali-part.mp3
# 52 Dataset/MER_Extra/happy/samsak_doveci_gurup_lacin.mp3
# 53 Dataset/MER_Extra/happy/hele_yar_zalim_yar_zekeriya_unlu.mp3
# 54 Dataset/MER_Extra/happy/maden_dagi_izzet_altinmese.mp3
# 55 Dataset/MER_Extra/happy/delalim_urfa_sira_geceleri.mp3
# 56 Dataset/MER_Extra/happy/panara_gel_ki_gorem_cesitli_sanatci.mp3
# 57 Dataset/MER_Extra/happy/antebin_hamamlar_cesitli_sanatci.mp3
# 58 Dataset/MER_Extra/happy/makarak_sari_baglar_kirac.mp3
# 59 Dataset/MER_Extra/happy/beyaz_gul_kirmizi_gul_ibrahim_tatlises.mp3
# 60 Dataset/MER_Extra/happy/gir_kanima_harun_kolcak.mp3
# 61 Dataset/MER_Extra/happy/uyu_demeye_geldim_melda_kuyucu.mp3
# 62 Dataset/MER_Extra/happy/daglar_kizi_reyhan_yusel_ozkasap.mp3
# 63 Dataset/MER_Extra/happy/ayas_yollar_sumer_ezgu.mp3
# 64 Dataset/MER_Extra/happy/esarbini_yan_baglama_ibrahim_tatlises.mp3
# 65 Dataset/MER_Extra/happy/bagya_girdimbag_budanmis_rustem.mp3
# 66 Dataset/MER_Extra/happy/fistan_bictim_dar_geldi_huriye_mustafa_keser.mp3
# 67 Dataset/MER_Extra/happy/arpa_bugday_daneler_muazzez_ersoy.mp3
# 68 Dataset/MER_Extra/happy/tridine_bandim_kubat.mp3
# 69 Dataset/MER_Extra/happy/kaslarin_karasina_gulsen_kutlu.mp3
# 70 Dataset/MER_Extra/happy/indim_havuz_basina_fasli_beyoglu.mp3
# 71 Dataset/MER_Extra/happy/gimildan_efe.mp3
# 72 Dataset/MER_Extra/happy/vay_surmeli_surmeli.mp3
# 73 Dataset/MER_Extra/happy/vardar_ovasi_fasli_beyoglu.mp3
# 74 Dataset/MER_Extra/happy/tatli_dile_guler_yuze_neset_ertas.mp3
# 75 Dataset/MER_Extra/happy/dugmeli_izzet_altinmese.mp3
# 76 Dataset/MER_Extra/happy/bahcelerde_borulce_eyll.mp3
# 77 Dataset/MER_Extra/happy/su_samsunun_evleri_imara.mp3
# 78 Dataset/MER_Extra/happy/adana_kopru_basi_murat_kursun.mp3
# 79 Dataset/MER_Extra/happy/ilvanlim_belkis_akkale.mp3
# 80 Dataset/MER_Extra/happy/sozlu_halay.mp3
# 81 Dataset/MER_Extra/happy/salinda_gel_orhan_hak_almaz.mp3
# 82 Dataset/MER_Extra/happy/zuhtu_sumer_ezgu.mp3
# 83 Dataset/MER_Extra/happy/bekar_gezelim_gurup_lacin.mp3
# 84 Dataset/MER_Extra/happy/osman_aga_seferad.mp3
# 85 Dataset/MER_Extra/happy/kesik_cayir_bedia_akarturk.mp3
# 86 Dataset/MER_Extra/happy/arap_kizi_ibrahim_tatlises.mp3
# 87 Dataset/MER_Extra/happy/yemeninde_hare_var_meski_fasil.mp3
# 88 Dataset/MER_Extra/happy/kiraz_dali_mehtap_koc.mp3
# 89 Dataset/MER_Extra/happy/ertan-ersan-oy-gelin-oy-damat-part.mp3
# 90 Dataset/MER_Extra/happy/cit_cit_cetene_ahmet_kurt.mp3
# 91 Dataset/MER_Extra/happy/dane_dane_benleri_var_burcin.mp3
# 92 Dataset/MER_Extra/happy/cal_para_suzan_kardes.mp3
# 93 Dataset/MER_Extra/happy/muhabbet_bagina_girdim.mp3
# 94 Dataset/MER_Extra/happy/comce_gelin_olasan_urfa.mp3
# 95 Dataset/MER_Extra/happy/rakkas_sezen_aksu.mp3
# 96 Dataset/MER_Extra/happy/merdivanim_kirik_oyun_havasi.mp3
# 97 Dataset/MER_Extra/happy/omer-faruk-bostan-erik-dali-part.mp3
# 98 Dataset/MER_Extra/happy/minnos_ceylan.mp3
# 99 Dataset/MER_Extra/happy/gokte_yildiz_aymisun.mp3
# 100 Dataset/MER_Extra/happy/kara_kopru_narliktir_cesitli_sanatci.mp3
# 101 Dataset/MER_Extra/sad/gitti_canimin_canani_cengiz_ozkan.mp3
# 102 Dataset/MER_Extra/sad/yazimi_kisa_cevirdin_muhlis_berberoglu.mp3
# 103 Dataset/MER_Extra/sad/kurdili_hicazkar_kanun_taksim.mp3
# 104 Dataset/MER_Extra/sad/yol_ver_daglar_arif_sag.mp3
# 105 Dataset/MER_Extra/sad/muhur_gozlum_cafer_nazlibas.mp3
# 106 Dataset/MER_Extra/sad/kendin_bilirsin_muslum_gurses.mp3
# 107 Dataset/MER_Extra/sad/seher_yildizi.mp3
# 108 Dataset/MER_Extra/sad/nikah_masasi_umit_besen.mp3
# 109 Dataset/MER_Extra/sad/asagidan_gelir_omuz_omuza_oguz_aksac.mp3
# 110 Dataset/MER_Extra/sad/kerpic_kerpic_ustune_erkan_ogur.mp3
# 111 Dataset/MER_Extra/sad/anilar_coskun_sabah.mp3
# 112 Dataset/MER_Extra/sad/gamzedeyim_deva_bulmam_muzeyyen_senar.mp3
# 113 Dataset/MER_Extra/sad/yuce_dag_basinda_yanar_bir_isik_sirri_lacin.mp3
# 114 Dataset/MER_Extra/sad/altin_hizma_mulayim_devrim_ates.mp3
# 115 Dataset/MER_Extra/sad/kalbimi_kira_kira.mp3
# 116 Dataset/MER_Extra/sad/kapildim_gidiyorum_melihat_gulses.mp3
# 117 Dataset/MER_Extra/sad/her_mevsim_bulent_ersoy.mp3
# 118 Dataset/MER_Extra/sad/derdim_coktur_erkan_ogur.mp3
# 119 Dataset/MER_Extra/sad/benim_yerimede_sev_sibelcan.mp3
# 120 Dataset/MER_Extra/sad/yemen_turkusu.mp3
# 121 Dataset/MER_Extra/sad/garip_saz_semaisi_goksel_baktagir.mp3
# 122 Dataset/MER_Extra/sad/o_yar_gelir.mp3
# 123 Dataset/MER_Extra/sad/odam_kirec_tutmuyor_gonen_molla.mp3
# 124 Dataset/MER_Extra/sad/buda_gelir_buda_gecer_arif_sag.mp3
# 125 Dataset/MER_Extra/sad/klarnet_taksim_mustafa_kandirali.mp3
# 126 Dataset/MER_Extra/sad/agladikca_ara_dinkjian.mp3
# 127 Dataset/MER_Extra/sad/lale_devri_sibel_can.mp3
# 128 Dataset/MER_Extra/sad/bir_muhabbet_kusu_zeki_muren.mp3
# 129 Dataset/MER_Extra/sad/leyla_mecnun_ud.mp3
# 130 Dataset/MER_Extra/sad/vazgectim_serkan_cagri.mp3
# 131 Dataset/MER_Extra/sad/seher_vaki_evinize_canan_cal.mp3
# 132 Dataset/MER_Extra/sad/harman_yeri_surseler_salih_gundogdu.mp3
# 133 Dataset/MER_Extra/sad/gelin_oldugun_gece_hakan_tasiyan.mp3
# 134 Dataset/MER_Extra/sad/uyan_sunam.mp3
# 135 Dataset/MER_Extra/sad/mor_salkimli_sokak_fatih_kisaparmak.mp3
# 136 Dataset/MER_Extra/sad/niye_cattin_kaslarini_umit_ates.mp3
# 137 Dataset/MER_Extra/sad/zuluf_dokmus_yuze_feyzi_yagci.mp3
# 138 Dataset/MER_Extra/sad/ben_kuskunum_felege_tsm.mp3
# 139 Dataset/MER_Extra/sad/kul_oldum_oyku_gurman.mp3
# 140 Dataset/MER_Extra/sad/kor_olsun_bu_askin_gozu_kor_olsun_muslum_gurses.mp3
# 141 Dataset/MER_Extra/sad/vurgun_muazzez_abaci.mp3
# 142 Dataset/MER_Extra/sad/yazimi_kisa_cevirdin.mp3
# 143 Dataset/MER_Extra/sad/yarim_senden_ayrilali_erkan_ogur.mp3
# 144 Dataset/MER_Extra/sad/dostum_dostum_kerim_yagci.mp3
# 145 Dataset/MER_Extra/sad/soyleyemem_derdimi_zeki_muren.mp3
# 146 Dataset/MER_Extra/sad/degme_benim_gamli_gonlume_umit_ates.mp3
# 147 Dataset/MER_Extra/sad/batan_gun_kana_benziyor_suat_sayin.mp3
# 148 Dataset/MER_Extra/sad/gulunce_gozlerinin_ici_guluyor_secil_heper.mp3
# 149 Dataset/MER_Extra/sad/kapildim_gidiyorum_bahtimin_ruzgarina.mp3
# 150 Dataset/MER_Extra/sad/kalbimi_kira_kira_sukran_ay.mp3
# 151 Dataset/MER_Extra/sad/degme_felek_cengiz_ozkan.mp3
# 152 Dataset/MER_Extra/sad/ben_gamli_hazan_zeki_muren.mp3
# 153 Dataset/MER_Extra/sad/kalbimin_tek_sahibine_irem_demirci.mp3
# 154 Dataset/MER_Extra/sad/bulbuller_dugun_eyler.mp3
# 155 Dataset/MER_Extra/sad/gule_yel_degdi_canan_cal.mp3
# 156 Dataset/MER_Extra/sad/deli_gonul_arif_sag.mp3
# 157 Dataset/MER_Extra/sad/geceler_dusman_gulay.mp3
# 158 Dataset/MER_Extra/sad/olumsuz_sevdim_arif_susam.mp3
# 159 Dataset/MER_Extra/sad/ben_gamli_hazan_melahat_pars.mp3
# 160 Dataset/MER_Extra/sad/unutma_beni_esmeray.mp3
# 161 Dataset/MER_Extra/sad/derin_derin_sevdalara_dalarsn_manus_baba.mp3
# 162 Dataset/MER_Extra/sad/degme_benim_gamli_yasli_gonlume_hakan_tasiyan.mp3
# 163 Dataset/MER_Extra/sad/suzan_suzi_incesaz.mp3
# 164 Dataset/MER_Extra/sad/karsida_gorunen_yayla_erkan_ogur.mp3
# 165 Dataset/MER_Extra/sad/sonu_yok_bu_askin_funda_arar.mp3
# 166 Dataset/MER_Extra/sad/bir_mektup_bir_resim_zeki_muren.mp3
# 167 Dataset/MER_Extra/sad/veda_busesi_zeki_muren.mp3
# 168 Dataset/MER_Extra/sad/unutmasin_hudai_aksu.mp3
# 169 Dataset/MER_Extra/sad/kendim_dustum_kalkabilirim_sibel_can.mp3
# 170 Dataset/MER_Extra/sad/kusura_fidanim.mp3
# 171 Dataset/MER_Extra/sad/sarkilara_sordum_soylemediler_emel_sayin.mp3
# 172 Dataset/MER_Extra/sad/suzan_suzi_cengiz_ozkan.mp3
# 173 Dataset/MER_Extra/sad/sevmekten_kim_usanir_hamiyet_yuceses.mp3
# 174 Dataset/MER_Extra/sad/hicaz_keman_taksim.mp3
# 175 Dataset/MER_Extra/sad/al_omrumu_cevdet_bagca.mp3
# 176 Dataset/MER_Extra/sad/geceler_yarim_oldu_ihsan_mendes.mp3
# 177 Dataset/MER_Extra/sad/her_mevsim_icimden_gelip_gecersin_hamiyet_yuceses.mp3
# 178 Dataset/MER_Extra/sad/carsambayi_sel_aldi_arslan_akyol.mp3
# 179 Dataset/MER_Extra/sad/sarkilar_seni_soyler_zeki_muren.mp3
# 180 Dataset/MER_Extra/sad/gullerin_icinden.mp3
# 181 Dataset/MER_Extra/sad/unutmamam_seni_zeki_muren.mp3
# 182 Dataset/MER_Extra/sad/eledim_eledim_eda_karaytug.mp3
# 183 Dataset/MER_Extra/sad/al_yazmalim.mp3
# 184 Dataset/MER_Extra/sad/nem_kaldi_gonen_molla.mp3
# 185 Dataset/MER_Extra/sad/gulunce_gozlerinin_ici_guluyor_behiye_aksoy.mp3
# 186 Dataset/MER_Extra/sad/derdimi_kimlere_desem_rusen_yilmaz.mp3
# 187 Dataset/MER_Extra/sad/mihriban_sirri_lacin.mp3
# 188 Dataset/MER_Extra/sad/senede_bir_gun_zeki_muren.mp3
# 189 Dataset/MER_Extra/sad/ben_yoruldum_hayat_mumin_sarikaya.mp3
# 190 Dataset/MER_Extra/sad/cokmu_gordunuz_ebru_gundes.mp3
# 191 Dataset/MER_Extra/sad/sevmekten_kim_usanir_muzzeyen_senar.mp3
# 192 Dataset/MER_Extra/sad/oy_beni_vurun_vurun_huseyin_ay.mp3
# 193 Dataset/MER_Extra/sad/su_kislanin_kapisina_orhan_hakalmaz.mp3
# 194 Dataset/MER_Extra/sad/sen_benden_gittin_gideli_erkan_ogur.mp3
# 195 Dataset/MER_Extra/sad/vazgectim_ara_dinkjian.mp3
# 196 Dataset/MER_Extra/sad/kader_diyemezsin_muazzez_ersoy.mp3
# 197 Dataset/MER_Extra/sad/aglama_yar_erkan_ogur.mp3
# 198 Dataset/MER_Extra/sad/sen_gelmez_oldun_piyano.mp3
# 199 Dataset/MER_Extra/sad/burasi_mustur.mp3
# 200 Dataset/MER_Extra/sad/uzun_ince_bir_yoldayim.mp3
# 201 Dataset/MER_Extra/angry/bu_sehir_arkandan_gelecek_dizi_muzigi.mp3
# 202 Dataset/MER_Extra/angry/yasak_elma_dizi_muzigi.mp3
# 203 Dataset/MER_Extra/angry/gunesin_kizlari_dizi_muzigi.mp3
# 204 Dataset/MER_Extra/angry/hekimoglu_turkusu.mp3
# 205 Dataset/MER_Extra/angry/survivor_ada_konseyi_muzigi.mp3
# 206 Dataset/MER_Extra/angry/medcezir_dizi_muzikleri.mp3
# 207 Dataset/MER_Extra/angry/hayat_sarkisi_diz_muzikleri2.mp3
# 208 Dataset/MER_Extra/angry/elif_dizi_muzigi.mp3
# 209 Dataset/MER_Extra/angry/eski_turk_sarkilari.mp3
# 210 Dataset/MER_Extra/angry/yazin_oykusu_dizi_muzigi.mp3
# 211 Dataset/MER_Extra/angry/kayit_disi_operasyon_dizi_muzikleri1.mp3
# 212 Dataset/MER_Extra/angry/eskiya_dunyaya_hukumdar_olmaz_2sezon_dizi_muzigi.mp3
# 213 Dataset/MER_Extra/angry/hayat_sarkisi_dizi_muzikleri1.mp3
# 214 Dataset/MER_Extra/angry/cendere_kurtlar_vadisi_dizi_muzikleri.mp3
# 215 Dataset/MER_Extra/angry/benim_hala_umudum_var_dizi_muzigi.mp3
# 216 Dataset/MER_Extra/angry/istanbullu_gelin_dizi_muzikleri.mp3
# 217 Dataset/MER_Extra/angry/kayit_disi_operasyon_dizi_muzikleri2.mp3
# 218 Dataset/MER_Extra/angry/desti_kpcak_turkleri.mp3
# 219 Dataset/MER_Extra/angry/kiraz_mevsimi_2.mp3
# 220 Dataset/MER_Extra/angry/isimsizler_dizi_muzikleri2.mp3
# 221 Dataset/MER_Extra/angry/cennetin_goz_yaslari_2_dizi_muzigi.mp3
# 222 Dataset/MER_Extra/angry/kara_sevda_dizi_muzigi1.mp3
# 223 Dataset/MER_Extra/angry/umuda_kelepce_vurulmaz_dizi_muzigi.mp3
# 224 Dataset/MER_Extra/angry/insanlik_sucu_dizi_muzikleri2.mp3
# 225 Dataset/MER_Extra/angry/isimsizler_dizi_muzikleri3.mp3
# 226 Dataset/MER_Extra/angry/isimsizler_dizi_muzikleri1.mp3
# 227 Dataset/MER_Extra/angry/dusundurdu_yine_beni_gozlerin_dizi_muzigi.mp3
# 228 Dataset/MER_Extra/angry/bir_cocuk_sevdim_dizi_muzigi.mp3
# 229 Dataset/MER_Extra/angry/icimdeki_firtina_dizi_muzikleri.mp3
# 230 Dataset/MER_Extra/angry/kara_sevda_dizi_muzigi2.mp3
# 231 Dataset/MER_Extra/angry/insanlik_sucu_dizi_muzikleri1.mp3
# 232 Dataset/MER_Extra/angry/siyah_beyaz_ask_dizi_muzigi.mp3
# 233 Dataset/MER_Extra/angry/avlu_dizi_muzikleri.mp3
# 234 Dataset/MER_Extra/angry/fatma_gulun_sucu_ne_dizi_muzigi.mp3
# 235 Dataset/MER_Extra/angry/cukur_dizi_muzigi2.mp3
# 236 Dataset/MER_Extra/angry/kaos_epik_savas_muzikleri.mp3
# 237 Dataset/MER_Extra/angry/seviyor_sevmiyor_dizi_muzigi.mp3
# 238 Dataset/MER_Extra/angry/arka_sokaklar_dizi_muzigi.mp3
# 239 Dataset/MER_Extra/angry/turk_askeri_savas_muzigi.mp3
# 240 Dataset/MER_Extra/angry/karagul_dizi_muzikleri.mp3
# 241 Dataset/MER_Extra/angry/yeter_dizi_muzigi.mp3
# 242 Dataset/MER_Extra/angry/adanli2.mp3
# 243 Dataset/MER_Extra/angry/ucurum_gerilim_alp_yenier.mp3
# 244 Dataset/MER_Extra/angry/sahsiyet_dizi_muzigi.mp3
# 245 Dataset/MER_Extra/angry/coban_yildizi_dizi_muzigi.mp3
# 246 Dataset/MER_Extra/angry/eskiya_dunyaya_hukumdar_olmaz_3sezon_dizi_muzigi.mp3
# 247 Dataset/MER_Extra/angry/ezel_dizi_muzigi2.mp3
# 248 Dataset/MER_Extra/angry/kalp_atisi.mp3
# 249 Dataset/MER_Extra/angry/adanali.mp3
# 250 Dataset/MER_Extra/angry/bir-zamanlar-cukur-ova-part.mp3
# 251 Dataset/MER_Extra/angry/fazilet_hanim_ve_kizlari_dizi_muzigi.mp3
# 252 Dataset/MER_Extra/angry/yuvamdaki_dusman_dizi_muzikleri.mp3
# 253 Dataset/MER_Extra/angry/hickirik_dizi_muzikleri.mp3
# 254 Dataset/MER_Extra/angry/ask_ve_mavi_dizi_muzigi.mp3
# 255 Dataset/MER_Extra/angry/erkenci-kus-dizi-muzigi-part.mp3
# 256 Dataset/MER_Extra/angry/tatar_gelin_dizi_muzikleri.mp3
# 257 Dataset/MER_Extra/angry/bir-litre-goz-yasi-part.mp3
# 258 Dataset/MER_Extra/angry/sana_bir_sir_verecegim_dizi_muzigi.mp3
# 259 Dataset/MER_Extra/angry/meryem_dizi_muzikleri2.mp3
# 260 Dataset/MER_Extra/angry/medcezir_dizi_muzikleri2.mp3
# 261 Dataset/MER_Extra/angry/kehribar_dizi_muzikleri.mp3
# 262 Dataset/MER_Extra/angry/doluna_dizi_muzigi.mp3
# 263 Dataset/MER_Extra/angry/soz_dizi_muzigi_3.mp3
# 264 Dataset/MER_Extra/angry/cukur_dizi_muzigi.mp3
# 265 Dataset/MER_Extra/angry/sen_anlat_karadeniz_dizi_muzigi.mp3
# 266 Dataset/MER_Extra/angry/beyaz_yalan_dizi_muzigi.mp3
# 267 Dataset/MER_Extra/angry/gullerin_savasi_dizi_muzigi.mp3
# 268 Dataset/MER_Extra/angry/filinta_dizi_muzigi1.mp3
# 269 Dataset/MER_Extra/angry/soz_dizi_muzigi_1.mp3
# 270 Dataset/MER_Extra/angry/eski_hikaye_dizi_muzigi.mp3
# 271 Dataset/MER_Extra/angry/meryem_dizi_muzikleri1.mp3
# 272 Dataset/MER_Extra/angry/dilan_hanim_dizi_muzigi.mp3
# 273 Dataset/MER_Extra/angry/kurtulus_filim_muzikleri.mp3
# 274 Dataset/MER_Extra/angry/kiraz_mevsimi_dizi_muzikleri.mp3
# 275 Dataset/MER_Extra/angry/yuvamdaki_dusman_dizi_muzikleri2.mp3
# 276 Dataset/MER_Extra/angry/yeni_ceri_marsi.mp3
# 277 Dataset/MER_Extra/angry/adini_Feriha_koydum.mp3
# 278 Dataset/MER_Extra/angry/gunesi_beklerken_dizi_muzigi.mp3
# 279 Dataset/MER_Extra/angry/arka_sokaklar_dizi_muzigi2.mp3
# 280 Dataset/MER_Extra/angry/not_defteri_dizi_muzikleri.mp3
# 281 Dataset/MER_Extra/angry/yer_gok_ask_dizi_muzikleri.mp3
# 282 Dataset/MER_Extra/angry/tatli_intikan_dizi_muzigi.mp3
# 283 Dataset/MER_Extra/angry/bugunun_saraylisi_dizi_mugizi.mp3
# 284 Dataset/MER_Extra/angry/ufak_tefek_cinayetler_dizi_muzigi.mp3
# 285 Dataset/MER_Extra/angry/genis_aile_dizi_muzigi.mp3
# 286 Dataset/MER_Extra/angry/osmanli_savas_marsi1.mp3
# 287 Dataset/MER_Extra/angry/kacak_dizi_muzikleri1.mp3
# 288 Dataset/MER_Extra/angry/ay_yildiz_tim_savas_muzigi.mp3
# 289 Dataset/MER_Extra/angry/cennetin_goz_yaslari_1_dizi_muzigi.mp3
# 290 Dataset/MER_Extra/angry/aksiyon_gerilim.mp3
# 291 Dataset/MER_Extra/angry/cilek_kokusu_dizi_muzigi.mp3
# 292 Dataset/MER_Extra/angry/canakkale_yolun_sonu_dizi_muzikleri.mp3
# 293 Dataset/MER_Extra/angry/cemberin_icinde_dizi_muzigi.mp3
# 294 Dataset/MER_Extra/angry/eskiya_dunyaya_hukumdar_olmaz_3_dizi_muzikleri.mp3
# 295 Dataset/MER_Extra/angry/dorduncu_murat_muzikleri.mp3
# 296 Dataset/MER_Extra/angry/araf_zaman_dizi_muzigi.mp3
# 297 Dataset/MER_Extra/angry/kacak_dizi_muzikleri2.mp3
# 298 Dataset/MER_Extra/angry/sungurlar_dizi_muzigi.mp3
# 299 Dataset/MER_Extra/angry/savasci_dizi_muzigi1.mp3
# 300 Dataset/MER_Extra/angry/turk_savas_muzigi1.mp3
# 301 Dataset/MER_Extra/relaxed/ben-yoruldum-hayat-part-cinar-cetinkaya-part.mp3
# 302 Dataset/MER_Extra/relaxed/julide_ozcelik_yalan_dunya.mp3
# 303 Dataset/MER_Extra/relaxed/fikret_kizilok_farketmeden.mp3
# 304 Dataset/MER_Extra/relaxed/serta_erener_tesaduf_ask.mp3
# 305 Dataset/MER_Extra/relaxed/mehmet_gureli_kimse_bilmez.mp3
# 306 Dataset/MER_Extra/relaxed/fikret_kizilok_basbasa.mp3
# 307 Dataset/MER_Extra/relaxed/bulent_ortacgil_yuzunu_dokme_kucuk_kiz.mp3
# 308 Dataset/MER_Extra/relaxed/julide_ozcelik_zaman.mp3
# 309 Dataset/MER_Extra/relaxed/fikret_kizilok_gonul.mp3
# 310 Dataset/MER_Extra/relaxed/kelebek_cigdem_Erkan.mp3
# 311 Dataset/MER_Extra/relaxed/berguzar_korel_kaybolan_yillar.mp3
# 312 Dataset/MER_Extra/relaxed/cigdem_erken_cakmak.mp3
# 313 Dataset/MER_Extra/relaxed/duman_elleri_ellerime.mp3
# 314 Dataset/MER_Extra/relaxed/demir_demirkan_doldur_kadehleri.mp3
# 315 Dataset/MER_Extra/relaxed/birsen_tezer_seher_vahti.mp3
# 316 Dataset/MER_Extra/relaxed/bulent_ortacgil_sana_geldim.mp3
# 317 Dataset/MER_Extra/relaxed/birsen_tezer_sarkicinin_sarkicisi.mp3
# 318 Dataset/MER_Extra/relaxed/nev_kimseye_etmem_sikayet.mp3
# 319 Dataset/MER_Extra/relaxed/onur_yardimci_bana_donme.mp3
# 320 Dataset/MER_Extra/relaxed/mor_ve_otesi_bisiklet.mp3
# 321 Dataset/MER_Extra/relaxed/ozdemir_erdogan_ac_kapiyi_gir_iceri.mp3
# 322 Dataset/MER_Extra/relaxed/ajda-pekkan-ya-sonra- Part.mp3
# 323 Dataset/MER_Extra/relaxed/bulent_ortacgil_sensiz_olmaz.mp3
# 324 Dataset/MER_Extra/relaxed/cigdem_erken_laleler.mp3
# 325 Dataset/MER_Extra/relaxed/vedat_sakman_usluca.mp3
# 326 Dataset/MER_Extra/relaxed/ayten_alpman_erkekler_aglamaz.mp3
# 327 Dataset/MER_Extra/relaxed/nilufer_ayrilik_hasreti.mp3
# 328 Dataset/MER_Extra/relaxed/ozan_musluoglu_kimse_duymasin.mp3
# 329 Dataset/MER_Extra/relaxed/nukhet_ruacan_her_sey_sevgiyle_baslar.mp3
# 330 Dataset/MER_Extra/relaxed/birsen_tezer_ciglik_cigliga.mp3
# 331 Dataset/MER_Extra/relaxed/ezgini_gunlugu_mutlu_son.mp3
# 332 Dataset/MER_Extra/relaxed/kimse_bilmez_kursat_basar.mp3
# 333 Dataset/MER_Extra/relaxed/ben_varim_kursat.mp3
# 334 Dataset/MER_Extra/relaxed/yalin_keske.mp3
# 335 Dataset/MER_Extra/relaxed/sene_sener_bak_bana.mp3
# 336 Dataset/MER_Extra/relaxed/julide_ozcelik_esitiz_eninde_sonunda.mp3
# 337 Dataset/MER_Extra/relaxed/pilli_bebek_cogu_zaman.mp3
# 338 Dataset/MER_Extra/relaxed/kimseye_etmem_sikayet.mp3
# 339 Dataset/MER_Extra/relaxed/bana_ellerini_ver_ozdemir_erdogan.mp3
# 340 Dataset/MER_Extra/relaxed/kendinle_kalirsin_julide_ozcelik.mp3
# 341 Dataset/MER_Extra/relaxed/mustafa_ceceli_elvan_gunaydin.mp3
# 342 Dataset/MER_Extra/relaxed/bulent_ortacgil_yagmur.mp3
# 343 Dataset/MER_Extra/relaxed/enbe_orkestrasi_hikaye.mp3
# 344 Dataset/MER_Extra/relaxed/mazi_kalbimde_bir_yaradir_dilek_turkan.mp3
# 345 Dataset/MER_Extra/relaxed/uyanma_uyu_selim_gungoren.mp3
# 346 Dataset/MER_Extra/relaxed/nim_sofyan_senden_bana_yar_olmaz.mp3
# 347 Dataset/MER_Extra/relaxed/sevince_erkin_koray.mp3
# 348 Dataset/MER_Extra/relaxed/eren_cilgin_mavi_yalan.mp3
# 349 Dataset/MER_Extra/relaxed/birsen_tezer_di_gel_yanima.mp3
# 350 Dataset/MER_Extra/relaxed/Birsen_tezer_istanbul.mp3
# 351 Dataset/MER_Extra/relaxed/fikret_kizilok_guzel_ne_guzel_olmussun.mp3
# 352 Dataset/MER_Extra/relaxed/julide_ozcelik_kimse_bilmez.mp3
# 353 Dataset/MER_Extra/relaxed/dusundukce_selen_gulun.mp3
# 354 Dataset/MER_Extra/relaxed/mabel_matis_supheli_sarkinin_sairi.mp3
# 355 Dataset/MER_Extra/relaxed/mfo_bodrum_bodrum.mp3
# 356 Dataset/MER_Extra/relaxed/cem_ozkan_don_bana.mp3
# 357 Dataset/MER_Extra/relaxed/sinan_kaynakci_kendine_zaman_ver.mp3
# 358 Dataset/MER_Extra/relaxed/zeynep_dizdar_vazgec_gonul.mp3
# 359 Dataset/MER_Extra/relaxed/sertap_erener_acik_adres.mp3
# 360 Dataset/MER_Extra/relaxed/birsen-tezer-bilsen-part.mp3
# 361 Dataset/MER_Extra/relaxed/sumru_agir_yuruyen_issiz.mp3
# 362 Dataset/MER_Extra/relaxed/aklim_hep_sende.mp3
# 363 Dataset/MER_Extra/relaxed/aysegul_aldinc_kucuk_seyler.mp3
# 364 Dataset/MER_Extra/relaxed/fikrimin-ince-gulu-tamer-zeytinoglu-part.mp3
# 365 Dataset/MER_Extra/relaxed/mert_royfe_zaman.mp3
# 366 Dataset/MER_Extra/relaxed/julide_ozcelik_kara_toprak.mp3
# 367 Dataset/MER_Extra/relaxed/sertap_erener_bahcede.mp3
# 368 Dataset/MER_Extra/relaxed/selim_gulgoren_uyanma_uyu.mp3
# 369 Dataset/MER_Extra/relaxed/mahsar_alanson_benim_hala_umudum_var.mp3
# 370 Dataset/MER_Extra/relaxed/fikret_kizilok_gecenin_ucunde.mp3
# 371 Dataset/MER_Extra/relaxed/tel_tel_taradim_nurten_demirkol.mp3
# 372 Dataset/MER_Extra/relaxed/kirac_kalbin_tek_arkadasi.mp3
# 373 Dataset/MER_Extra/relaxed/sumru_agir_yuruyen_terk_edilmis_kent.mp3
# 374 Dataset/MER_Extra/relaxed/ozdemir-erdogan-baharda-kuslar-gibi-part.mp3
# 375 Dataset/MER_Extra/relaxed/sebnem_ferah_yagmurlar.mp3
# 376 Dataset/MER_Extra/relaxed/fikret_kizilok_bosuna.mp3
# 377 Dataset/MER_Extra/relaxed/erol_evgin_bir_ilk_bahar_sabahi.mp3
# 378 Dataset/MER_Extra/relaxed/feridun_duzagac_sevgi.mp3
# 379 Dataset/MER_Extra/relaxed/yine_yazi_bekleriz_tnk.mp3
# 380 Dataset/MER_Extra/relaxed/zeynep_dizdar_bir_cocuk_sevdim.mp3
# 381 Dataset/MER_Extra/relaxed/julide_ozcelik_siradan_bir_gun.mp3
# 382 Dataset/MER_Extra/relaxed/alp_ersonmez_burada_yarali_biri_var.mp3
# 383 Dataset/MER_Extra/relaxed/fikret_kizilok_gidiyorsun.mp3
# 384 Dataset/MER_Extra/relaxed/julide_ozcelik_bugun_neden_gelmedin.mp3
# 385 Dataset/MER_Extra/relaxed/sigaramin-dumani-tamer-zeytinoglu-part.mp3
# 386 Dataset/MER_Extra/relaxed/fikret_kizilok_ben_gidersem.mp3
# 387 Dataset/MER_Extra/relaxed/ezginin_gunlugu_kiyisiz_deniz.mp3
# 388 Dataset/MER_Extra/relaxed/tanju_duru_aklim_hep_sende.mp3
# 389 Dataset/MER_Extra/relaxed/teoman_senden_once_senden_sonra.mp3
# 390 Dataset/MER_Extra/relaxed/elvan_gunaydin.mp3
# 391 Dataset/MER_Extra/relaxed/ezginin_gunlugu_ask_yuzunden.mp3
# 392 Dataset/MER_Extra/relaxed/roya_gemiciler.mp3
# 393 Dataset/MER_Extra/relaxed/basak_yavuz_gidersen.mp3
# 394 Dataset/MER_Extra/relaxed/tnk_yine_yazi_bekleriz.mp3
# 395 Dataset/MER_Extra/relaxed/sevinc_tevz_ve_ben_yalniz.mp3
# 396 Dataset/MER_Extra/relaxed/sumru_agir_yuruyen_guz_defteri.mp3
# 397 Dataset/MER_Extra/relaxed/onur_mete_bu_asktan_gidiyorum.mp3
# 398 Dataset/MER_Extra/relaxed/demir_demircan_aci_nefes.mp3
# 399 Dataset/MER_Extra/relaxed/yalin_ki_sen.mp3
# 400 Dataset/MER_Extra/relaxed/sarp_madem_ortadaki_gecit.mp3

# %% [markdown]
# ### 2.2 Data Cleaning
#
# #### 1. Checking Duration
# Because the audio duration is not same, the duration is unified to equal length with 30s, if the duration is too short, the outlier might be dropped as it contains little information.

# %%
duration = []
for i in range(len(filewithdir)):
    y,sr = librosa.load(filewithdir[i])
    duration.append(librosa.get_duration(y=y,sr=sr))

# %%
for i in range(len(duration)):
    if duration[i]<25.5:
        print(i, duration[i])
# Out:
# 70 10.08
# 103 10.08

# %%
duration.remove(duration[70])
filewithdir.remove(filewithdir[70])

# %%
duration.remove(duration[102])
filewithdir.remove(filewithdir[102])

# %%
duration_extra = []
for i in range(len(filewithdir_extra)):
    y,sr = librosa.load(filewithdir_extra[i])
    duration_extra.append(librosa.get_duration(y=y,sr=sr))
# Out:
# [src/libmpg123/layer3.c:INT123_do_layer3():1844] error: dequantization failed!

# %%
for i in range(len(duration_extra)):
    if duration_extra[i]<25.5:
        print(i, duration_extra[i])

# %% [markdown]
# #### 2. Resize the audio clips to equal length
# Crop all the audio files to length to 25.5s

# %%
path25 = "Dataset25/MER_25/" #output dir

for i in range(len(filewithdir)):
    song = AudioSegment.from_mp3(filewithdir[i])  
    
    # cut to the audio clips to 25.5s
    new = song[:25500]
        
    folder = os.path.basename(os.path.dirname(filewithdir[i]))
    path_new = path25 + folder + "/" + os.path.basename(filewithdir[i])
    new.export(path_new,format = "mp3")

# %%
dir25 = "Dataset25/MER_25"
data25 = os.listdir(dir25)
file_dir25 = []
count = 0

for mooddir25 in data25:
    if(not r'.' in mooddir25):
        moodDirName25 = os.path.join(dir25,mooddir25)
        mooddir25=np.array(os.listdir(moodDirName25))
        for audio in mooddir25:
            if(audio[-3:]=='mp3'):
                count+=1
                fn=os.path.join(moodDirName25,audio)
                file_dir25.append(fn)
                print(str(count),fn)
# Out:
# 1 Dataset25/MER_25/Q1/MT0009845271.mp3
# 2 Dataset25/MER_25/Q1/MT0012742379.mp3
# 3 Dataset25/MER_25/Q1/MT0009188643.mp3
# 4 Dataset25/MER_25/Q1/MT0011560587.mp3
# 5 Dataset25/MER_25/Q1/MT0001605268.mp3
# 6 Dataset25/MER_25/Q1/MT0005832516.mp3
# 7 Dataset25/MER_25/Q1/MT0007147603.mp3
# 8 Dataset25/MER_25/Q1/MT0033940994.mp3
# 9 Dataset25/MER_25/Q1/MT0014576739.mp3
# 10 Dataset25/MER_25/Q1/MT0000392975.mp3
# 11 Dataset25/MER_25/Q1/MT0013389935.mp3
# 12 Dataset25/MER_25/Q1/MT0004037272.mp3
# 13 Dataset25/MER_25/Q1/MT0011916674.mp3
# 14 Dataset25/MER_25/Q1/MT0002033629.mp3
# 15 Dataset25/MER_25/Q1/MT0005737276.mp3
# 16 Dataset25/MER_25/Q1/MT0002119439.mp3
# 17 Dataset25/MER_25/Q1/MT0003044417.mp3
# 18 Dataset25/MER_25/Q1/MT0003788939.mp3
# 19 Dataset25/MER_25/Q1/MT0015742096.mp3
# 20 Dataset25/MER_25/Q1/MT0008276791.mp3
# 21 Dataset25/MER_25/Q1/MT0027159893.mp3
# 22 Dataset25/MER_25/Q1/MT0011957429.mp3
# 23 Dataset25/MER_25/Q1/MT0008575372.mp3
# 24 Dataset25/MER_25/Q1/MT0003170370.mp3
# 25 Dataset25/MER_25/Q1/MT0002222957.mp3
# 26 Dataset25/MER_25/Q1/MT0001757676.mp3
# 27 Dataset25/MER_25/Q1/MT0002262181.mp3
# 28 Dataset25/MER_25/Q1/MT0003669917.mp3
# 29 Dataset25/MER_25/Q1/MT0010487769.mp3
# 30 Dataset25/MER_25/Q1/MT0026753600.mp3
# 31 Dataset25/MER_25/Q1/MT0026753827.mp3
# 32 Dataset25/MER_25/Q1/MT0008675527.mp3
# 33 Dataset25/MER_25/Q1/MT0012846850.mp3
# 34 Dataset25/MER_25/Q1/MT0008222676.mp3
# 35 Dataset25/MER_25/Q1/MT0005003824.mp3
# 36 Dataset25/MER_25/Q1/MT0004339430.mp3
# 37 Dataset25/MER_25/Q1/MT0001703346.mp3
# 38 Dataset25/MER_25/Q1/MT0036368550.mp3
# 39 Dataset25/MER_25/Q1/MT0031544440.mp3
# 40 Dataset25/MER_25/Q1/MT0027035970.mp3
# 41 Dataset25/MER_25/Q1/MT0003286463.mp3
# 42 Dataset25/MER_25/Q1/MT0009897495.mp3
# 43 Dataset25/MER_25/Q1/MT0005331755.mp3
# 44 Dataset25/MER_25/Q1/MT0009845276.mp3
# 45 Dataset25/MER_25/Q1/MT0029874624.mp3
# 46 Dataset25/MER_25/Q1/MT0011104152.mp3
# 47 Dataset25/MER_25/Q1/MT0002595792.mp3
# 48 Dataset25/MER_25/Q1/MT0004428604.mp3
# 49 Dataset25/MER_25/Q1/MT0011574534.mp3
# 50 Dataset25/MER_25/Q1/MT0028445777.mp3
# 51 Dataset25/MER_25/Q1/MT0003243311.mp3
# 52 Dataset25/MER_25/Q1/MT0001340713.mp3
# 53 Dataset25/MER_25/Q1/MT0001418045.mp3
# 54 Dataset25/MER_25/Q1/MT0007013069.mp3
# 55 Dataset25/MER_25/Q1/MT0005163122.mp3
# 56 Dataset25/MER_25/Q1/MT0002366291.mp3
# 57 Dataset25/MER_25/Q1/MT0018031959.mp3
# 58 Dataset25/MER_25/Q1/MT0002525905.mp3
# 59 Dataset25/MER_25/Q1/MT0007439502.mp3
# 60 Dataset25/MER_25/Q1/MT0018617125.mp3
# 61 Dataset25/MER_25/Q1/MT0009845275.mp3
# 62 Dataset25/MER_25/Q1/MT0029065626.mp3
# 63 Dataset25/MER_25/Q1/MT0014586720.mp3
# 64 Dataset25/MER_25/Q1/MT0005083488.mp3
# 65 Dataset25/MER_25/Q1/MT0015934550.mp3
# 66 Dataset25/MER_25/Q1/MT0013590244.mp3
# 67 Dataset25/MER_25/Q1/MT0031922089.mp3
# 68 Dataset25/MER_25/Q1/MT0003570082.mp3
# 69 Dataset25/MER_25/Q1/MT0027478016.mp3
# 70 Dataset25/MER_25/Q1/MT0011575842.mp3
# 71 Dataset25/MER_25/Q1/MT0006747288.mp3
# 72 Dataset25/MER_25/Q1/MT0031996897.mp3
# 73 Dataset25/MER_25/Q1/MT0010465830.mp3
# 74 Dataset25/MER_25/Q1/MT0009904717.mp3
# 75 Dataset25/MER_25/Q1/MT0003248394.mp3
# 76 Dataset25/MER_25/Q1/MT0030484925.mp3
# 77 Dataset25/MER_25/Q1/MT0001671399.mp3
# 78 Dataset25/MER_25/Q1/MT0004896738.mp3
# 79 Dataset25/MER_25/Q1/MT0003949060.mp3
# 80 Dataset25/MER_25/Q1/MT0001680969.mp3
# 81 Dataset25/MER_25/Q1/MT0009213083.mp3
# 82 Dataset25/MER_25/Q1/MT0003603772.mp3
# 83 Dataset25/MER_25/Q1/MT0000040632.mp3
# 84 Dataset25/MER_25/Q1/MT0001586807.mp3
# 85 Dataset25/MER_25/Q1/MT0011997914.mp3
# 86 Dataset25/MER_25/Q1/MT0010900969.mp3
# 87 Dataset25/MER_25/Q1/MT0007057303.mp3
# 88 Dataset25/MER_25/Q1/MT0034988131.mp3
# 89 Dataset25/MER_25/Q1/MT0026727455.mp3
# 90 Dataset25/MER_25/Q1/MT0003272751.mp3
# 91 Dataset25/MER_25/Q1/MT0000442827.mp3
# 92 Dataset25/MER_25/Q1/MT0001335920.mp3
# 93 Dataset25/MER_25/Q1/MT0010617945.mp3
# 94 Dataset25/MER_25/Q1/MT0010085729.mp3
# 95 Dataset25/MER_25/Q1/MT0003594672.mp3
# 96 Dataset25/MER_25/Q1/MT0008972801.mp3
# 97 Dataset25/MER_25/Q1/MT0034125967.mp3
# 98 Dataset25/MER_25/Q1/MT0002794078.mp3
# 99 Dataset25/MER_25/Q1/MT0028648077.mp3
# 100 Dataset25/MER_25/Q1/MT0010501618.mp3
# 101 Dataset25/MER_25/Q1/MT0004683099.mp3
# 102 Dataset25/MER_25/Q1/MT0006096934.mp3
# 103 Dataset25/MER_25/Q1/MT0011950450.mp3
# 104 Dataset25/MER_25/Q1/MT0033443279.mp3
# 105 Dataset25/MER_25/Q1/MT0005469880.mp3
# 106 Dataset25/MER_25/Q1/MT0012041920.mp3
# 107 Dataset25/MER_25/Q1/MT0009729892.mp3
# 108 Dataset25/MER_25/Q1/MT0006996768.mp3
# 109 Dataset25/MER_25/Q1/MT0001189913.mp3
# 110 Dataset25/MER_25/Q1/MT0013633209.mp3
# 111 Dataset25/MER_25/Q1/MT0028627699.mp3
# 112 Dataset25/MER_25/Q1/MT0009208842.mp3
# 113 Dataset25/MER_25/Q1/MT0005625762.mp3
# 114 Dataset25/MER_25/Q1/MT0002161109.mp3
# 115 Dataset25/MER_25/Q1/MT0008644609.mp3
# 116 Dataset25/MER_25/Q1/MT0017797643.mp3
# 117 Dataset25/MER_25/Q1/MT0004751933.mp3
# 118 Dataset25/MER_25/Q1/MT0003144898.mp3
# 119 Dataset25/MER_25/Q1/MT0005478759.mp3
# 120 Dataset25/MER_25/Q1/MT0028220133.mp3
# 121 Dataset25/MER_25/Q1/MT0032061241.mp3
# 122 Dataset25/MER_25/Q1/MT0028495262.mp3
# 123 Dataset25/MER_25/Q1/MT0013101577.mp3
# 124 Dataset25/MER_25/Q1/MT0032405040.mp3
# 125 Dataset25/MER_25/Q1/MT0008340316.mp3
# 126 Dataset25/MER_25/Q1/MT0013235939.mp3
# 127 Dataset25/MER_25/Q1/MT0010694663.mp3
# 128 Dataset25/MER_25/Q1/MT0012534566.mp3
# 129 Dataset25/MER_25/Q1/MT0009202768.mp3
# 130 Dataset25/MER_25/Q1/MT0002698706.mp3
# 131 Dataset25/MER_25/Q1/MT0001753457.mp3
# 132 Dataset25/MER_25/Q1/MT0004122617.mp3
# 133 Dataset25/MER_25/Q1/MT0004711079.mp3
# 134 Dataset25/MER_25/Q1/MT0002391847.mp3
# 135 Dataset25/MER_25/Q1/MT0008401073.mp3
# 136 Dataset25/MER_25/Q1/MT0011869625.mp3
# 137 Dataset25/MER_25/Q1/MT0007443823.mp3
# 138 Dataset25/MER_25/Q1/MT0006540794.mp3
# 139 Dataset25/MER_25/Q1/MT0000249842.mp3
# 140 Dataset25/MER_25/Q1/MT0006315323.mp3
# 141 Dataset25/MER_25/Q1/MT0006640857.mp3
# 142 Dataset25/MER_25/Q1/MT0005713768.mp3
# 143 Dataset25/MER_25/Q1/MT0015680193.mp3
# 144 Dataset25/MER_25/Q1/MT0000414517.mp3
# 145 Dataset25/MER_25/Q1/MT0002297016.mp3
# 146 Dataset25/MER_25/Q1/MT0000992846.mp3
# 147 Dataset25/MER_25/Q1/MT0005523766.mp3
# 148 Dataset25/MER_25/Q1/MT0011786799.mp3
# 149 Dataset25/MER_25/Q1/MT0032181833.mp3
# 150 Dataset25/MER_25/Q1/MT0003390733.mp3
# 151 Dataset25/MER_25/Q1/MT0002532237.mp3
# 152 Dataset25/MER_25/Q1/MT0011739779.mp3
# 153 Dataset25/MER_25/Q1/MT0002351905.mp3
# 154 Dataset25/MER_25/Q1/MT0010489498.mp3
# 155 Dataset25/MER_25/Q1/MT0003213835.mp3
# 156 Dataset25/MER_25/Q1/MT0033841575.mp3
# 157 Dataset25/MER_25/Q1/MT0029492542.mp3
# 158 Dataset25/MER_25/Q1/MT0000082187.mp3
# 159 Dataset25/MER_25/Q1/MT0034555338.mp3
# 160 Dataset25/MER_25/Q1/MT0012798988.mp3
# 161 Dataset25/MER_25/Q1/MT0027048677.mp3
# 162 Dataset25/MER_25/Q1/MT0015005100.mp3
# 163 Dataset25/MER_25/Q1/MT0006367176.mp3
# 164 Dataset25/MER_25/Q1/MT0002538335.mp3
# 165 Dataset25/MER_25/Q1/MT0013350034.mp3
# 166 Dataset25/MER_25/Q1/MT0012601428.mp3
# 167 Dataset25/MER_25/Q1/MT0012202513.mp3
# 168 Dataset25/MER_25/Q1/MT0005239610.mp3
# 169 Dataset25/MER_25/Q1/MT0005674518.mp3
# 170 Dataset25/MER_25/Q1/MT0018450519.mp3
# 171 Dataset25/MER_25/Q1/MT0018651126.mp3
# 172 Dataset25/MER_25/Q1/MT0004141823.mp3
# 173 Dataset25/MER_25/Q1/MT0002053300.mp3
# 174 Dataset25/MER_25/Q1/MT0001053268.mp3
# 175 Dataset25/MER_25/Q1/MT0000364027.mp3
# 176 Dataset25/MER_25/Q1/MT0018029465.mp3
# 177 Dataset25/MER_25/Q1/MT0008684922.mp3
# 178 Dataset25/MER_25/Q1/MT0005752234.mp3
# 179 Dataset25/MER_25/Q1/MT0028617657.mp3
# 180 Dataset25/MER_25/Q1/MT0010344415.mp3
# 181 Dataset25/MER_25/Q1/MT0014650360.mp3
# 182 Dataset25/MER_25/Q1/MT0001236649.mp3
# 183 Dataset25/MER_25/Q1/MT0010392442.mp3
# 184 Dataset25/MER_25/Q1/MT0011354857.mp3
# 185 Dataset25/MER_25/Q1/MT0030487841.mp3
# 186 Dataset25/MER_25/Q1/MT0033958450.mp3
# 187 Dataset25/MER_25/Q1/MT0001217651.mp3
# 188 Dataset25/MER_25/Q1/MT0012331779.mp3
# 189 Dataset25/MER_25/Q1/MT0004447226.mp3
# 190 Dataset25/MER_25/Q1/MT0001521543.mp3
# 191 Dataset25/MER_25/Q1/MT0026158301.mp3
# 192 Dataset25/MER_25/Q1/MT0011930865.mp3
# 193 Dataset25/MER_25/Q1/MT0002894033.mp3
# 194 Dataset25/MER_25/Q1/MT0009010830.mp3
# 195 Dataset25/MER_25/Q1/MT0008363839.mp3
# 196 Dataset25/MER_25/Q1/MT0032892262.mp3
# 197 Dataset25/MER_25/Q1/MT0018024152.mp3
# 198 Dataset25/MER_25/Q1/MT0033397838.mp3
# 199 Dataset25/MER_25/Q1/MT0007067293.mp3
# 200 Dataset25/MER_25/Q1/MT0003724610.mp3
# 201 Dataset25/MER_25/Q1/MT0012396528.mp3
# 202 Dataset25/MER_25/Q1/MT0003903675.mp3
# 203 Dataset25/MER_25/Q1/MT0032235381.mp3
# 204 Dataset25/MER_25/Q1/MT0005265641.mp3
# 205 Dataset25/MER_25/Q1/MT0033415296.mp3
# 206 Dataset25/MER_25/Q1/MT0015028144.mp3
# 207 Dataset25/MER_25/Q1/MT0016972827.mp3
# 208 Dataset25/MER_25/Q1/MT0000664362.mp3
# 209 Dataset25/MER_25/Q1/MT0009378909.mp3
# 210 Dataset25/MER_25/Q1/MT0027002641.mp3
# 211 Dataset25/MER_25/Q1/MT0007840454.mp3
# 212 Dataset25/MER_25/Q1/MT0011564855.mp3
# 213 Dataset25/MER_25/Q1/MT0026795261.mp3
# 214 Dataset25/MER_25/Q1/MT0003794106.mp3
# 215 Dataset25/MER_25/Q1/MT0004032071.mp3
# 216 Dataset25/MER_25/Q1/MT0011999773.mp3
# 217 Dataset25/MER_25/Q1/MT0013800071.mp3
# 218 Dataset25/MER_25/Q1/MT0004669603.mp3
# 371 Dataset25/MER_25/Q2/MT0005606947.mp3
# 372 Dataset25/MER_25/Q2/MT0005595173.mp3
# 373 Dataset25/MER_25/Q2/MT0011259078.mp3
# 374 Dataset25/MER_25/Q2/MT0009217411.mp3
# 375 Dataset25/MER_25/Q2/MT0026898936.mp3
# 376 Dataset25/MER_25/Q2/MT0014997916.mp3
# 377 Dataset25/MER_25/Q2/MT0004759588.mp3
# 378 Dataset25/MER_25/Q2/MT0012914763.mp3
# 379 Dataset25/MER_25/Q2/MT0003209662.mp3
# 380 Dataset25/MER_25/Q2/MT0000377411.mp3
# 381 Dataset25/MER_25/Q2/MT0000133200.mp3
# 382 Dataset25/MER_25/Q2/MT0033287096.mp3
# 383 Dataset25/MER_25/Q2/MT0008733057.mp3
# 384 Dataset25/MER_25/Q2/MT0003546058.mp3
# 385 Dataset25/MER_25/Q2/MT0004459450.mp3
# 386 Dataset25/MER_25/Q2/MT0001376988.mp3
# 387 Dataset25/MER_25/Q2/MT0005951020.mp3
# 388 Dataset25/MER_25/Q2/MT0007413949.mp3
# 389 Dataset25/MER_25/Q2/MT0001766004.mp3
# 390 Dataset25/MER_25/Q2/MT0005387539.mp3
# 391 Dataset25/MER_25/Q2/MT0004715422.mp3
# 392 Dataset25/MER_25/Q2/MT0006001707.mp3
# 393 Dataset25/MER_25/Q2/MT0004942017.mp3
# 394 Dataset25/MER_25/Q2/MT0008570712.mp3
# 395 Dataset25/MER_25/Q2/MT0003807077.mp3
# 396 Dataset25/MER_25/Q2/MT0015971175.mp3
# 397 Dataset25/MER_25/Q2/MT0005897799.mp3
# 398 Dataset25/MER_25/Q2/MT0001975228.mp3
# 399 Dataset25/MER_25/Q2/MT0007926918.mp3
# 400 Dataset25/MER_25/Q2/MT0003639120.mp3
# 401 Dataset25/MER_25/Q2/MT0005550288.mp3
# 402 Dataset25/MER_25/Q2/MT0028172888.mp3
# 403 Dataset25/MER_25/Q2/MT0034816599.mp3
# 404 Dataset25/MER_25/Q2/MT0007535042.mp3
# 405 Dataset25/MER_25/Q2/MT0028469910.mp3
# 406 Dataset25/MER_25/Q2/MT0002399275.mp3
# 407 Dataset25/MER_25/Q2/MT0006810990.mp3
# 408 Dataset25/MER_25/Q2/MT0004558461.mp3
# 409 Dataset25/MER_25/Q2/MT0004882280.mp3
# 410 Dataset25/MER_25/Q2/MT0012116237.mp3
# 411 Dataset25/MER_25/Q2/MT0004956006.mp3
# 412 Dataset25/MER_25/Q2/MT0003136077.mp3
# 413 Dataset25/MER_25/Q2/MT0014878397.mp3
# 414 Dataset25/MER_25/Q2/MT0004867185.mp3
# 415 Dataset25/MER_25/Q2/MT0030124886.mp3
# 416 Dataset25/MER_25/Q2/MT0006520567.mp3
# 417 Dataset25/MER_25/Q2/MT0007799677.mp3
# 418 Dataset25/MER_25/Q2/MT0004293364.mp3
# 419 Dataset25/MER_25/Q2/MT0030203729.mp3
# 420 Dataset25/MER_25/Q2/MT0001927746.mp3
# 421 Dataset25/MER_25/Q2/MT0000729701.mp3
# 422 Dataset25/MER_25/Q2/MT0006292011.mp3
# 423 Dataset25/MER_25/Q2/MT0012008752.mp3
# 424 Dataset25/MER_25/Q2/MT0008361425.mp3
# 425 Dataset25/MER_25/Q2/MT0014703649.mp3
# 426 Dataset25/MER_25/Q2/MT0012855159.mp3
# 427 Dataset25/MER_25/Q2/MT0030160582.mp3
# 428 Dataset25/MER_25/Q2/MT0007379559.mp3
# 429 Dataset25/MER_25/Q2/MT0010983830.mp3
# 430 Dataset25/MER_25/Q2/MT0010490157.mp3
# 431 Dataset25/MER_25/Q2/MT0004511265.mp3
# 432 Dataset25/MER_25/Q2/MT0013824918.mp3
# 433 Dataset25/MER_25/Q2/MT0028750297.mp3
# 434 Dataset25/MER_25/Q2/MT0030214520.mp3
# 435 Dataset25/MER_25/Q2/MT0006564487.mp3
# 436 Dataset25/MER_25/Q2/MT0003782002.mp3
# 437 Dataset25/MER_25/Q2/MT0015541501.mp3
# 438 Dataset25/MER_25/Q2/MT0003349423.mp3
# 439 Dataset25/MER_25/Q2/MT0001419145.mp3
# 440 Dataset25/MER_25/Q2/MT0005202791.mp3
# 441 Dataset25/MER_25/Q2/MT0033097471.mp3
# 442 Dataset25/MER_25/Q2/MT0009601423.mp3
# 443 Dataset25/MER_25/Q2/MT0006798861.mp3
# 444 Dataset25/MER_25/Q2/MT0002385077.mp3
# 445 Dataset25/MER_25/Q2/MT0004958762.mp3
# 446 Dataset25/MER_25/Q2/MT0000971834.mp3
# 447 Dataset25/MER_25/Q2/MT0009800907.mp3
# 448 Dataset25/MER_25/Q2/MT0005751512.mp3
# 449 Dataset25/MER_25/Q4/MT0030369896.mp3
# 450 Dataset25/MER_25/Q4/MT0015706588.mp3
# 451 Dataset25/MER_25/Q4/MT0006164654.mp3
# 452 Dataset25/MER_25/Q4/MT0013176970.mp3
# 453 Dataset25/MER_25/Q4/MT0012862507.mp3
# 454 Dataset25/MER_25/Q4/MT0000711493.mp3
# 455 Dataset25/MER_25/Q4/MT0011376343.mp3
# 456 Dataset25/MER_25/Q4/MT0030495725.mp3
# 457 Dataset25/MER_25/Q4/MT0016897938.mp3
# 458 Dataset25/MER_25/Q4/MT0034212119.mp3
# 459 Dataset25/MER_25/Q4/MT0007342701.mp3
# 460 Dataset25/MER_25/Q4/MT0005850999.mp3
# 461 Dataset25/MER_25/Q4/MT0000821772.mp3
# 462 Dataset25/MER_25/Q4/MT0007039041.mp3
# 463 Dataset25/MER_25/Q4/MT0011250965.mp3
# 464 Dataset25/MER_25/Q4/MT0007064420.mp3
# 465 Dataset25/MER_25/Q4/MT0000235880.mp3
# 466 Dataset25/MER_25/Q4/MT0013177702.mp3
# 467 Dataset25/MER_25/Q4/MT0011862487.mp3
# 468 Dataset25/MER_25/Q4/MT0031886830.mp3
# 469 Dataset25/MER_25/Q4/MT0004584067.mp3
# 470 Dataset25/MER_25/Q4/MT0030442334.mp3
# 471 Dataset25/MER_25/Q4/MT0004089549.mp3
# 472 Dataset25/MER_25/Q4/MT0006254062.mp3
# 473 Dataset25/MER_25/Q4/MT0028813196.mp3
# 474 Dataset25/MER_25/Q4/MT0000092267.mp3
# 475 Dataset25/MER_25/Q4/MT0027835071.mp3
# 476 Dataset25/MER_25/Q4/MT0004274911.mp3
# 477 Dataset25/MER_25/Q4/MT0002714805.mp3
# 478 Dataset25/MER_25/Q4/MT0006107326.mp3
# 479 Dataset25/MER_25/Q4/MT0013095380.mp3
# 480 Dataset25/MER_25/Q4/MT0002811975.mp3
# 481 Dataset25/MER_25/Q4/MT0003366948.mp3
# 482 Dataset25/MER_25/Q4/MT0009769814.mp3
# 483 Dataset25/MER_25/Q4/MT0029080694.mp3
# 484 Dataset25/MER_25/Q4/MT0001624303.mp3
# 485 Dataset25/MER_25/Q4/MT0029976595.mp3
# 486 Dataset25/MER_25/Q4/MT0012383717.mp3
# 487 Dataset25/MER_25/Q4/MT0005798527.mp3
# 488 Dataset25/MER_25/Q4/MT0005261375.mp3
# 489 Dataset25/MER_25/Q4/MT0003778826.mp3
# 490 Dataset25/MER_25/Q4/MT0031807708.mp3
# 491 Dataset25/MER_25/Q4/MT0001942272.mp3
# 492 Dataset25/MER_25/Q4/MT0004537445.mp3
# 493 Dataset25/MER_25/Q4/MT0030286920.mp3
# 494 Dataset25/MER_25/Q4/MT0035000258.mp3
# 495 Dataset25/MER_25/Q4/MT0008342962.mp3
# 496 Dataset25/MER_25/Q4/MT0017672677.mp3
# 497 Dataset25/MER_25/Q4/MT0000762097.mp3
# 498 Dataset25/MER_25/Q4/MT0007453719.mp3
# 499 Dataset25/MER_25/Q4/MT0005550441.mp3
# 500 Dataset25/MER_25/Q4/MT0028596249.mp3
# 501 Dataset25/MER_25/Q4/MT0034005433.mp3
# 502 Dataset25/MER_25/Q4/MT0027100467.mp3
# 503 Dataset25/MER_25/Q4/MT0030319227.mp3
# 504 Dataset25/MER_25/Q4/MT0007186714.mp3
# 505 Dataset25/MER_25/Q4/MT0004867564.mp3
# 506 Dataset25/MER_25/Q4/MT0028550964.mp3
# 507 Dataset25/MER_25/Q4/MT0004850690.mp3
# 508 Dataset25/MER_25/Q4/MT0001641228.mp3
# 509 Dataset25/MER_25/Q4/MT0029553110.mp3
# 510 Dataset25/MER_25/Q4/MT0004093767.mp3
# 511 Dataset25/MER_25/Q4/MT0005884980.mp3
# 512 Dataset25/MER_25/Q4/MT0014489361.mp3
# 513 Dataset25/MER_25/Q4/MT0026919017.mp3
# 514 Dataset25/MER_25/Q4/MT0010855214.mp3
# 515 Dataset25/MER_25/Q4/MT0007556029.mp3
# 516 Dataset25/MER_25/Q4/MT0031826774.mp3
# 517 Dataset25/MER_25/Q4/MT0007207968.mp3
# 518 Dataset25/MER_25/Q4/MT0001594582.mp3
# 519 Dataset25/MER_25/Q4/MT0013486354.mp3
# 520 Dataset25/MER_25/Q4/MT0000218346.mp3
# 521 Dataset25/MER_25/Q4/MT0005695311.mp3
# 522 Dataset25/MER_25/Q4/MT0003280103.mp3
# 523 Dataset25/MER_25/Q4/MT0002448379.mp3
# 524 Dataset25/MER_25/Q4/MT0034106363.mp3
# 525 Dataset25/MER_25/Q4/MT0010998105.mp3
# 526 Dataset25/MER_25/Q4/MT0034015731.mp3
# 527 Dataset25/MER_25/Q4/MT0007833171.mp3
# 528 Dataset25/MER_25/Q4/MT0012222183.mp3
# 529 Dataset25/MER_25/Q4/MT0030097602.mp3
# 530 Dataset25/MER_25/Q4/MT0007107079.mp3
# 531 Dataset25/MER_25/Q4/MT0006037085.mp3
# 532 Dataset25/MER_25/Q4/MT0012112600.mp3
# 533 Dataset25/MER_25/Q4/MT0004911454.mp3
# 534 Dataset25/MER_25/Q4/MT0001494812.mp3
# 535 Dataset25/MER_25/Q4/MT0001870847.mp3
# 536 Dataset25/MER_25/Q4/MT0008686594.mp3
# 537 Dataset25/MER_25/Q4/MT0001195535.mp3
# 538 Dataset25/MER_25/Q4/MT0028066739.mp3
# 539 Dataset25/MER_25/Q4/MT0010818060.mp3
# 540 Dataset25/MER_25/Q4/MT0012027536.mp3
# 541 Dataset25/MER_25/Q4/MT0005091539.mp3
# 542 Dataset25/MER_25/Q4/MT0015849191.mp3
# 543 Dataset25/MER_25/Q4/MT0027976714.mp3
# 544 Dataset25/MER_25/Q4/MT0005285696.mp3
# 545 Dataset25/MER_25/Q4/MT0016887233.mp3
# 546 Dataset25/MER_25/Q4/MT0011886148.mp3
# 547 Dataset25/MER_25/Q4/MT0004036096.mp3
# 548 Dataset25/MER_25/Q4/MT0005608787.mp3
# 549 Dataset25/MER_25/Q4/MT0005074629.mp3
# 550 Dataset25/MER_25/Q4/MT0001438043.mp3
# 551 Dataset25/MER_25/Q4/MT0011906602.mp3
# 552 Dataset25/MER_25/Q4/MT0010758927.mp3
# 553 Dataset25/MER_25/Q4/MT0028709149.mp3
# 554 Dataset25/MER_25/Q4/MT0031495046.mp3
# 555 Dataset25/MER_25/Q4/MT0007232134.mp3
# 556 Dataset25/MER_25/Q4/MT0014475915.mp3
# 557 Dataset25/MER_25/Q4/MT0000661847.mp3
# 558 Dataset25/MER_25/Q4/MT0002846256.mp3
# 559 Dataset25/MER_25/Q4/MT0009741521.mp3
# 560 Dataset25/MER_25/Q4/MT0001394087.mp3
# 561 Dataset25/MER_25/Q4/MT0001768550.mp3
# 562 Dataset25/MER_25/Q4/MT0007766156.mp3
# 563 Dataset25/MER_25/Q4/MT0006117018.mp3
# 564 Dataset25/MER_25/Q4/MT0000202045.mp3
# 565 Dataset25/MER_25/Q4/MT0026776967.mp3
# 566 Dataset25/MER_25/Q4/MT0000336135.mp3
# 567 Dataset25/MER_25/Q4/MT0014584319.mp3
# 568 Dataset25/MER_25/Q4/MT0012888230.mp3
# 569 Dataset25/MER_25/Q4/MT0010979481.mp3
# 570 Dataset25/MER_25/Q4/MT0000054705.mp3
# 571 Dataset25/MER_25/Q4/MT0003022328.mp3
# 572 Dataset25/MER_25/Q4/MT0011938737.mp3
# 573 Dataset25/MER_25/Q4/MT0012794033.mp3
# 574 Dataset25/MER_25/Q4/MT0010203716.mp3
# 575 Dataset25/MER_25/Q4/MT0000369789.mp3
# 576 Dataset25/MER_25/Q4/MT0010665248.mp3
# 577 Dataset25/MER_25/Q4/MT0009075362.mp3
# 578 Dataset25/MER_25/Q4/MT0010984486.mp3
# 579 Dataset25/MER_25/Q4/MT0028374210.mp3
# 580 Dataset25/MER_25/Q4/MT0030036616.mp3
# 581 Dataset25/MER_25/Q4/MT0030481897.mp3
# 582 Dataset25/MER_25/Q4/MT0034186620.mp3
# 583 Dataset25/MER_25/Q4/MT0034577404.mp3
# 584 Dataset25/MER_25/Q4/MT0033410438.mp3
# 585 Dataset25/MER_25/Q4/MT0013280170.mp3
# 586 Dataset25/MER_25/Q4/MT0031827474.mp3
# 587 Dataset25/MER_25/Q4/MT0015026293.mp3
# 588 Dataset25/MER_25/Q4/MT0001661022.mp3
# 589 Dataset25/MER_25/Q4/MT0000901959.mp3
# 590 Dataset25/MER_25/Q4/MT0000348553.mp3
# 591 Dataset25/MER_25/Q4/MT0030282917.mp3
# 592 Dataset25/MER_25/Q4/MT0001980613.mp3
# 593 Dataset25/MER_25/Q4/MT0012151268.mp3
# 594 Dataset25/MER_25/Q4/MT0034148562.mp3
# 595 Dataset25/MER_25/Q4/MT0006352493.mp3
# 596 Dataset25/MER_25/Q4/MT0009289348.mp3
# 597 Dataset25/MER_25/Q4/MT0007119529.mp3
# 598 Dataset25/MER_25/Q4/MT0003956612.mp3
# 599 Dataset25/MER_25/Q4/MT0012893353.mp3
# 600 Dataset25/MER_25/Q4/MT0034203861.mp3
# 601 Dataset25/MER_25/Q4/MT0011702301.mp3
# 602 Dataset25/MER_25/Q4/MT0034160981.mp3
# 603 Dataset25/MER_25/Q4/MT0008665212.mp3
# 604 Dataset25/MER_25/Q4/MT0007053424.mp3
# 605 Dataset25/MER_25/Q4/MT0009185069.mp3
# 606 Dataset25/MER_25/Q4/MT0014134790.mp3
# 607 Dataset25/MER_25/Q4/MT0003454112.mp3
# 608 Dataset25/MER_25/Q4/MT0013676763.mp3
# 609 Dataset25/MER_25/Q4/MT0013411556.mp3
# 610 Dataset25/MER_25/Q4/MT0031898123.mp3
# 611 Dataset25/MER_25/Q4/MT0011051663.mp3
# 612 Dataset25/MER_25/Q4/MT0000550961.mp3
# 613 Dataset25/MER_25/Q4/MT0001511433.mp3
# 614 Dataset25/MER_25/Q4/MT0000746822.mp3
# 615 Dataset25/MER_25/Q4/MT0000636335.mp3
# 616 Dataset25/MER_25/Q4/MT0034186195.mp3
# 617 Dataset25/MER_25/Q4/MT0003025046.mp3
# 618 Dataset25/MER_25/Q4/MT0012766840.mp3
# 619 Dataset25/MER_25/Q4/MT0006955716.mp3
# 620 Dataset25/MER_25/Q4/MT0010965655.mp3
# 621 Dataset25/MER_25/Q4/MT0008167476.mp3
# 622 Dataset25/MER_25/Q4/MT0014507179.mp3
# 623 Dataset25/MER_25/Q4/MT0026608644.mp3
# 624 Dataset25/MER_25/Q4/MT0033461826.mp3
# 625 Dataset25/MER_25/Q4/MT0000203193.mp3
# 626 Dataset25/MER_25/Q4/MT0010810859.mp3
# 627 Dataset25/MER_25/Q4/MT0002834532.mp3
# 628 Dataset25/MER_25/Q4/MT0004331116.mp3
# 629 Dataset25/MER_25/Q4/MT0010485603.mp3
# 630 Dataset25/MER_25/Q4/MT0000698081.mp3
# 631 Dataset25/MER_25/Q4/MT0009991160.mp3
# 632 Dataset25/MER_25/Q4/MT0000922312.mp3
# 633 Dataset25/MER_25/Q4/MT0011922080.mp3
# 634 Dataset25/MER_25/Q4/MT0012941049.mp3
# 635 Dataset25/MER_25/Q4/MT0005656534.mp3
# 636 Dataset25/MER_25/Q4/MT0000980148.mp3
# 637 Dataset25/MER_25/Q4/MT0001109401.mp3
# 638 Dataset25/MER_25/Q4/MT0011380622.mp3
# 639 Dataset25/MER_25/Q4/MT0033391280.mp3
# 640 Dataset25/MER_25/Q4/MT0001877603.mp3
# 641 Dataset25/MER_25/Q4/MT0006983241.mp3
# 642 Dataset25/MER_25/Q4/MT0015659520.mp3
# 643 Dataset25/MER_25/Q4/MT0004833310.mp3
# 644 Dataset25/MER_25/Q4/MT0011922905.mp3
# 645 Dataset25/MER_25/Q4/MT0010842738.mp3
# 646 Dataset25/MER_25/Q4/MT0013955066.mp3
# 647 Dataset25/MER_25/Q4/MT0001058887.mp3
# 648 Dataset25/MER_25/Q4/MT0017667847.mp3
# 649 Dataset25/MER_25/Q4/MT0002698827.mp3
# 650 Dataset25/MER_25/Q4/MT0028335228.mp3
# 651 Dataset25/MER_25/Q4/MT0030007733.mp3
# 652 Dataset25/MER_25/Q4/MT0004759106.mp3
# 653 Dataset25/MER_25/Q4/MT0000522789.mp3
# 654 Dataset25/MER_25/Q4/MT0030494794.mp3
# 655 Dataset25/MER_25/Q4/MT0032698237.mp3
# 656 Dataset25/MER_25/Q4/MT0012333553.mp3
# 657 Dataset25/MER_25/Q4/MT0016932218.mp3
# 658 Dataset25/MER_25/Q4/MT0010707508.mp3
# 659 Dataset25/MER_25/Q4/MT0033326377.mp3
# 660 Dataset25/MER_25/Q4/MT0002674708.mp3
# 661 Dataset25/MER_25/Q4/MT0000460427.mp3
# 662 Dataset25/MER_25/Q4/MT0015653546.mp3
# 663 Dataset25/MER_25/Q4/MT0001676671.mp3
# 664 Dataset25/MER_25/Q4/MT0005987148.mp3
# 665 Dataset25/MER_25/Q4/MT0002124238.mp3
# 666 Dataset25/MER_25/Q4/MT0006769480.mp3
# 667 Dataset25/MER_25/Q4/MT0011895175.mp3
# 668 Dataset25/MER_25/Q4/MT0003710207.mp3
# 669 Dataset25/MER_25/Q4/MT0000888329.mp3
# 670 Dataset25/MER_25/Q4/MT0002132088.mp3
# 671 Dataset25/MER_25/Q4/MT0013673733.mp3
# 672 Dataset25/MER_25/Q4/MT0007087238.mp3
# 673 Dataset25/MER_25/Q4/MT0005129157.mp3
# 674 Dataset25/MER_25/Q3/MT0000523076.mp3
# 675 Dataset25/MER_25/Q3/MT0007265208.mp3
# 676 Dataset25/MER_25/Q3/MT0004842694.mp3
# 881 Dataset25/MER_25/Q3/MT0002142155.mp3
# 882 Dataset25/MER_25/Q3/MT0004817670.mp3
# 883 Dataset25/MER_25/Q3/MT0011440705.mp3
# 884 Dataset25/MER_25/Q3/MT0013173557.mp3
# 885 Dataset25/MER_25/Q3/MT0011308097.mp3
# 886 Dataset25/MER_25/Q3/MT0001523435.mp3
# 887 Dataset25/MER_25/Q3/MT0005981667.mp3
# 888 Dataset25/MER_25/Q3/MT0003037596.mp3
# 889 Dataset25/MER_25/Q3/MT0031693432.mp3
# 890 Dataset25/MER_25/Q3/MT0002986568.mp3
# 891 Dataset25/MER_25/Q3/MT0005115042.mp3
# 892 Dataset25/MER_25/Q3/MT0008979040.mp3
# 893 Dataset25/MER_25/Q3/MT0001844620.mp3
# 894 Dataset25/MER_25/Q3/MT0010804974.mp3
# 895 Dataset25/MER_25/Q3/MT0000796526.mp3
# 896 Dataset25/MER_25/Q3/MT0015664499.mp3
# 897 Dataset25/MER_25/Q3/MT0012292188.mp3
# 898 Dataset25/MER_25/Q3/MT0004342301.mp3

# %%
duration_25 = []
for i in range(len(file_dir25)):
    y,sr = librosa.load(file_dir25[i])
    d = librosa.get_duration(y=y,sr=sr)
    duration_25.append(d)

# %%
# Check duration again
for i in range(len(duration_25)):
    if duration_25[i]!=25.5:
        print(i,duration_25[i])

# %%
path25_extra = "Dataset25/MER_Extra25/" #output dir

for i in range(len(filewithdir_extra)):
    song = AudioSegment.from_mp3(filewithdir_extra[i])  
    
    # cut to the audio clips to 25.5s
    new = song[:25500]
        
    folder = os.path.basename(os.path.dirname(filewithdir_extra[i]))
    path_new = path25_extra + folder + "/" + os.path.basename(filewithdir_extra[i])
    new.export(path_new,format = "mp3")

# %%
dir25_extra = "Dataset25/MER_Extra25"
data25_extra = os.listdir(dir25_extra)
file_dir25_extra = []
count_extra = 0

for mooddir25 in data25_extra:
    if(not r'.' in mooddir25):
        moodDirName25 = os.path.join(dir25_extra,mooddir25)
        mooddir25=np.array(os.listdir(moodDirName25))
        for audio in mooddir25:
            if(audio[-3:]=='mp3'):
                count_extra+=1
                fn=os.path.join(moodDirName25,audio)
                file_dir25_extra.append(fn)
                print(str(count_extra),fn)
# Out:
# 1 Dataset25/MER_Extra25/happy/ovalar_gurup_yol.mp3
# 2 Dataset25/MER_Extra25/happy/cekirge_oguz_yilmaz.mp3
# 3 Dataset25/MER_Extra25/happy/baran_bayraktar_gol.mp3
# 4 Dataset25/MER_Extra25/happy/bu_gece_uyumamisan.mp3
# 5 Dataset25/MER_Extra25/happy/kim_arar_nilufer.mp3
# 6 Dataset25/MER_Extra25/happy/heycan_serdar_ortac.mp3
# 7 Dataset25/MER_Extra25/happy/su_gelen_atlimidir.mp3
# 8 Dataset25/MER_Extra25/happy/yuru_dilber_yuru_fasil.mp3
# 9 Dataset25/MER_Extra25/happy/arzu_kus_adana_kopru_basi.mp3
# 10 Dataset25/MER_Extra25/happy/evlere_senlik_sinan_ozen.mp3
# 11 Dataset25/MER_Extra25/happy/ayse_ozyilmazel_pardon.mp3
# 12 Dataset25/MER_Extra25/happy/yangin_olur_biz_yangina_gideriz_fasli_beyoglu.mp3
# 13 Dataset25/MER_Extra25/happy/uskudara_gideriken.mp3
# 14 Dataset25/MER_Extra25/happy/cay_elinden_oteye_sevval_sam.mp3
# 15 Dataset25/MER_Extra25/happy/mustafa_sandal_aya_benzer.mp3
# 16 Dataset25/MER_Extra25/happy/gul_doktum_yollarina_tarkan.mp3
# 17 Dataset25/MER_Extra25/happy/sevinc_sarivea_yandirgin_kalbimi_aman.mp3
# 18 Dataset25/MER_Extra25/happy/sigaramin_duman_meski_fasil.mp3
# 19 Dataset25/MER_Extra25/happy/mektebin_bacalari_yahya_cekirge.mp3
# 20 Dataset25/MER_Extra25/happy/siverek_asmasiyam_ibrahim_tatlises.mp3
# 21 Dataset25/MER_Extra25/happy/cakmak_cakmaga_geldik_cesitli_sanatci.mp3
# 22 Dataset25/MER_Extra25/happy/kalenin_bedenleri_zara.mp3
# 23 Dataset25/MER_Extra25/happy/beyoglunda_gezersin.mp3
# 24 Dataset25/MER_Extra25/happy/erkilet_guzeli_meski_fasil.mp3
# 25 Dataset25/MER_Extra25/happy/aynali_koruk_zara.mp3
# 26 Dataset25/MER_Extra25/happy/kocari_kazim_koyuncu.mp3
# 27 Dataset25/MER_Extra25/happy/zeytin_yapragi_yesil_zara.mp3
# 28 Dataset25/MER_Extra25/happy/ayva_cicek_acmis_fasli_beyoglu.mp3
# 29 Dataset25/MER_Extra25/happy/sendeki_kaslar_suzan_kardes.mp3
# 30 Dataset25/MER_Extra25/happy/bag_gel_bostana_gel_kubat.mp3
# 31 Dataset25/MER_Extra25/happy/ah_nerede_vah_nerede_fusun_onal.mp3
# 32 Dataset25/MER_Extra25/happy/yar_saclarin_lule_lule_nesrin_sipahi.mp3
# 33 Dataset25/MER_Extra25/happy/diyar_bakir_guzel_baglar_yahya_cekirge.mp3
# 34 Dataset25/MER_Extra25/happy/kadifeden_kesesi_fasli_beyoglu.mp3
# 35 Dataset25/MER_Extra25/happy/mardin_kapisindan_atyalyamadm_kazanc_bedih.mp3
# 36 Dataset25/MER_Extra25/happy/son_verdim_kalbimin_issine_seyyal_taner.mp3
# 37 Dataset25/MER_Extra25/happy/darildinmi_cicim_bana_fasli_beyoglu.mp3
# 38 Dataset25/MER_Extra25/happy/karabiberim_serdar_ortac.mp3
# 39 Dataset25/MER_Extra25/happy/gulum_benim_muazzez_ersoy.mp3
# 40 Dataset25/MER_Extra25/happy/gozleri_aska_gulen_funda_arar.mp3
# 41 Dataset25/MER_Extra25/happy/yola_ciktim_mardine_berdan.mp3
# 42 Dataset25/MER_Extra25/happy/antebin_kalesine_ibrahim_tatlises.mp3
# 43 Dataset25/MER_Extra25/happy/hadi_gari_sende_gel.mp3
# 44 Dataset25/MER_Extra25/happy/yuksek_yuksek_tepelere.mp3
# 45 Dataset25/MER_Extra25/happy/diyarbakir_lorke_halayi.mp3
# 46 Dataset25/MER_Extra25/happy/askimiz_bitecek_cansu_koc.mp3
# 47 Dataset25/MER_Extra25/happy/altun_kardesler_erik_dali.mp3
# 48 Dataset25/MER_Extra25/happy/aya_benzer_mustafa_sandal.mp3
# 49 Dataset25/MER_Extra25/happy/davullu_zurnali_oyun_havasi.mp3
# 50 Dataset25/MER_Extra25/happy/kondurama_kum_doldu_cesitli_sanatci.mp3
# 51 Dataset25/MER_Extra25/happy/murat-kursun-erik-dali-part.mp3
# 52 Dataset25/MER_Extra25/happy/samsak_doveci_gurup_lacin.mp3
# 53 Dataset25/MER_Extra25/happy/hele_yar_zalim_yar_zekeriya_unlu.mp3
# 54 Dataset25/MER_Extra25/happy/maden_dagi_izzet_altinmese.mp3
# 55 Dataset25/MER_Extra25/happy/delalim_urfa_sira_geceleri.mp3
# 56 Dataset25/MER_Extra25/happy/panara_gel_ki_gorem_cesitli_sanatci.mp3
# 57 Dataset25/MER_Extra25/happy/antebin_hamamlar_cesitli_sanatci.mp3
# 58 Dataset25/MER_Extra25/happy/makarak_sari_baglar_kirac.mp3
# 59 Dataset25/MER_Extra25/happy/beyaz_gul_kirmizi_gul_ibrahim_tatlises.mp3
# 60 Dataset25/MER_Extra25/happy/gir_kanima_harun_kolcak.mp3
# 61 Dataset25/MER_Extra25/happy/uyu_demeye_geldim_melda_kuyucu.mp3
# 62 Dataset25/MER_Extra25/happy/daglar_kizi_reyhan_yusel_ozkasap.mp3
# 63 Dataset25/MER_Extra25/happy/ayas_yollar_sumer_ezgu.mp3
# 64 Dataset25/MER_Extra25/happy/esarbini_yan_baglama_ibrahim_tatlises.mp3
# 65 Dataset25/MER_Extra25/happy/bagya_girdimbag_budanmis_rustem.mp3
# 66 Dataset25/MER_Extra25/happy/fistan_bictim_dar_geldi_huriye_mustafa_keser.mp3
# 67 Dataset25/MER_Extra25/happy/arpa_bugday_daneler_muazzez_ersoy.mp3
# 68 Dataset25/MER_Extra25/happy/tridine_bandim_kubat.mp3
# 69 Dataset25/MER_Extra25/happy/kaslarin_karasina_gulsen_kutlu.mp3
# 70 Dataset25/MER_Extra25/happy/indim_havuz_basina_fasli_beyoglu.mp3
# 71 Dataset25/MER_Extra25/happy/gimildan_efe.mp3
# 72 Dataset25/MER_Extra25/happy/vay_surmeli_surmeli.mp3
# 73 Dataset25/MER_Extra25/happy/vardar_ovasi_fasli_beyoglu.mp3
# 74 Dataset25/MER_Extra25/happy/tatli_dile_guler_yuze_neset_ertas.mp3
# 75 Dataset25/MER_Extra25/happy/dugmeli_izzet_altinmese.mp3
# 76 Dataset25/MER_Extra25/happy/bahcelerde_borulce_eyll.mp3
# 77 Dataset25/MER_Extra25/happy/su_samsunun_evleri_imara.mp3
# 78 Dataset25/MER_Extra25/happy/adana_kopru_basi_murat_kursun.mp3
# 79 Dataset25/MER_Extra25/happy/ilvanlim_belkis_akkale.mp3
# 80 Dataset25/MER_Extra25/happy/sozlu_halay.mp3
# 81 Dataset25/MER_Extra25/happy/salinda_gel_orhan_hak_almaz.mp3
# 82 Dataset25/MER_Extra25/happy/zuhtu_sumer_ezgu.mp3
# 83 Dataset25/MER_Extra25/happy/bekar_gezelim_gurup_lacin.mp3
# 84 Dataset25/MER_Extra25/happy/osman_aga_seferad.mp3
# 85 Dataset25/MER_Extra25/happy/kesik_cayir_bedia_akarturk.mp3
# 86 Dataset25/MER_Extra25/happy/arap_kizi_ibrahim_tatlises.mp3
# 87 Dataset25/MER_Extra25/happy/yemeninde_hare_var_meski_fasil.mp3
# 88 Dataset25/MER_Extra25/happy/kiraz_dali_mehtap_koc.mp3
# 89 Dataset25/MER_Extra25/happy/ertan-ersan-oy-gelin-oy-damat-part.mp3
# 90 Dataset25/MER_Extra25/happy/cit_cit_cetene_ahmet_kurt.mp3
# 91 Dataset25/MER_Extra25/happy/dane_dane_benleri_var_burcin.mp3
# 92 Dataset25/MER_Extra25/happy/cal_para_suzan_kardes.mp3
# 93 Dataset25/MER_Extra25/happy/muhabbet_bagina_girdim.mp3
# 94 Dataset25/MER_Extra25/happy/comce_gelin_olasan_urfa.mp3
# 95 Dataset25/MER_Extra25/happy/rakkas_sezen_aksu.mp3
# 96 Dataset25/MER_Extra25/happy/merdivanim_kirik_oyun_havasi.mp3
# 97 Dataset25/MER_Extra25/happy/omer-faruk-bostan-erik-dali-part.mp3
# 98 Dataset25/MER_Extra25/happy/minnos_ceylan.mp3
# 99 Dataset25/MER_Extra25/happy/gokte_yildiz_aymisun.mp3
# 100 Dataset25/MER_Extra25/happy/kara_kopru_narliktir_cesitli_sanatci.mp3
# 101 Dataset25/MER_Extra25/sad/gitti_canimin_canani_cengiz_ozkan.mp3
# 102 Dataset25/MER_Extra25/sad/yazimi_kisa_cevirdin_muhlis_berberoglu.mp3
# 103 Dataset25/MER_Extra25/sad/kurdili_hicazkar_kanun_taksim.mp3
# 104 Dataset25/MER_Extra25/sad/yol_ver_daglar_arif_sag.mp3
# 105 Dataset25/MER_Extra25/sad/muhur_gozlum_cafer_nazlibas.mp3
# 106 Dataset25/MER_Extra25/sad/kendin_bilirsin_muslum_gurses.mp3
# 107 Dataset25/MER_Extra25/sad/seher_yildizi.mp3
# 108 Dataset25/MER_Extra25/sad/nikah_masasi_umit_besen.mp3
# 109 Dataset25/MER_Extra25/sad/asagidan_gelir_omuz_omuza_oguz_aksac.mp3
# 110 Dataset25/MER_Extra25/sad/kerpic_kerpic_ustune_erkan_ogur.mp3
# 111 Dataset25/MER_Extra25/sad/anilar_coskun_sabah.mp3
# 112 Dataset25/MER_Extra25/sad/gamzedeyim_deva_bulmam_muzeyyen_senar.mp3
# 113 Dataset25/MER_Extra25/sad/yuce_dag_basinda_yanar_bir_isik_sirri_lacin.mp3
# 114 Dataset25/MER_Extra25/sad/altin_hizma_mulayim_devrim_ates.mp3
# 115 Dataset25/MER_Extra25/sad/kalbimi_kira_kira.mp3
# 116 Dataset25/MER_Extra25/sad/kapildim_gidiyorum_melihat_gulses.mp3
# 117 Dataset25/MER_Extra25/sad/her_mevsim_bulent_ersoy.mp3
# 118 Dataset25/MER_Extra25/sad/derdim_coktur_erkan_ogur.mp3
# 119 Dataset25/MER_Extra25/sad/benim_yerimede_sev_sibelcan.mp3
# 120 Dataset25/MER_Extra25/sad/yemen_turkusu.mp3
# 121 Dataset25/MER_Extra25/sad/garip_saz_semaisi_goksel_baktagir.mp3
# 122 Dataset25/MER_Extra25/sad/o_yar_gelir.mp3
# 123 Dataset25/MER_Extra25/sad/odam_kirec_tutmuyor_gonen_molla.mp3
# 124 Dataset25/MER_Extra25/sad/buda_gelir_buda_gecer_arif_sag.mp3
# 125 Dataset25/MER_Extra25/sad/klarnet_taksim_mustafa_kandirali.mp3
# 126 Dataset25/MER_Extra25/sad/agladikca_ara_dinkjian.mp3
# 127 Dataset25/MER_Extra25/sad/lale_devri_sibel_can.mp3
# 128 Dataset25/MER_Extra25/sad/bir_muhabbet_kusu_zeki_muren.mp3
# 129 Dataset25/MER_Extra25/sad/leyla_mecnun_ud.mp3
# 130 Dataset25/MER_Extra25/sad/vazgectim_serkan_cagri.mp3
# 131 Dataset25/MER_Extra25/sad/seher_vaki_evinize_canan_cal.mp3
# 132 Dataset25/MER_Extra25/sad/harman_yeri_surseler_salih_gundogdu.mp3
# 133 Dataset25/MER_Extra25/sad/gelin_oldugun_gece_hakan_tasiyan.mp3
# 134 Dataset25/MER_Extra25/sad/uyan_sunam.mp3
# 135 Dataset25/MER_Extra25/sad/mor_salkimli_sokak_fatih_kisaparmak.mp3
# 136 Dataset25/MER_Extra25/sad/niye_cattin_kaslarini_umit_ates.mp3
# 137 Dataset25/MER_Extra25/sad/zuluf_dokmus_yuze_feyzi_yagci.mp3
# 138 Dataset25/MER_Extra25/sad/ben_kuskunum_felege_tsm.mp3
# 139 Dataset25/MER_Extra25/sad/kul_oldum_oyku_gurman.mp3
# 140 Dataset25/MER_Extra25/sad/kor_olsun_bu_askin_gozu_kor_olsun_muslum_gurses.mp3
# 141 Dataset25/MER_Extra25/sad/vurgun_muazzez_abaci.mp3
# 142 Dataset25/MER_Extra25/sad/yazimi_kisa_cevirdin.mp3
# 143 Dataset25/MER_Extra25/sad/yarim_senden_ayrilali_erkan_ogur.mp3
# 144 Dataset25/MER_Extra25/sad/dostum_dostum_kerim_yagci.mp3
# 145 Dataset25/MER_Extra25/sad/soyleyemem_derdimi_zeki_muren.mp3
# 146 Dataset25/MER_Extra25/sad/degme_benim_gamli_gonlume_umit_ates.mp3
# 147 Dataset25/MER_Extra25/sad/batan_gun_kana_benziyor_suat_sayin.mp3
# 148 Dataset25/MER_Extra25/sad/gulunce_gozlerinin_ici_guluyor_secil_heper.mp3
# 149 Dataset25/MER_Extra25/sad/kapildim_gidiyorum_bahtimin_ruzgarina.mp3
# 150 Dataset25/MER_Extra25/sad/kalbimi_kira_kira_sukran_ay.mp3
# 151 Dataset25/MER_Extra25/sad/degme_felek_cengiz_ozkan.mp3
# 152 Dataset25/MER_Extra25/sad/ben_gamli_hazan_zeki_muren.mp3
# 153 Dataset25/MER_Extra25/sad/kalbimin_tek_sahibine_irem_demirci.mp3
# 154 Dataset25/MER_Extra25/sad/bulbuller_dugun_eyler.mp3
# 155 Dataset25/MER_Extra25/sad/gule_yel_degdi_canan_cal.mp3
# 156 Dataset25/MER_Extra25/sad/deli_gonul_arif_sag.mp3
# 157 Dataset25/MER_Extra25/sad/geceler_dusman_gulay.mp3
# 158 Dataset25/MER_Extra25/sad/olumsuz_sevdim_arif_susam.mp3
# 159 Dataset25/MER_Extra25/sad/ben_gamli_hazan_melahat_pars.mp3
# 160 Dataset25/MER_Extra25/sad/unutma_beni_esmeray.mp3
# 161 Dataset25/MER_Extra25/sad/derin_derin_sevdalara_dalarsn_manus_baba.mp3
# 162 Dataset25/MER_Extra25/sad/degme_benim_gamli_yasli_gonlume_hakan_tasiyan.mp3
# 163 Dataset25/MER_Extra25/sad/suzan_suzi_incesaz.mp3
# 164 Dataset25/MER_Extra25/sad/karsida_gorunen_yayla_erkan_ogur.mp3
# 165 Dataset25/MER_Extra25/sad/sonu_yok_bu_askin_funda_arar.mp3
# 166 Dataset25/MER_Extra25/sad/bir_mektup_bir_resim_zeki_muren.mp3
# 167 Dataset25/MER_Extra25/sad/veda_busesi_zeki_muren.mp3
# 168 Dataset25/MER_Extra25/sad/unutmasin_hudai_aksu.mp3
# 169 Dataset25/MER_Extra25/sad/kendim_dustum_kalkabilirim_sibel_can.mp3
# 170 Dataset25/MER_Extra25/sad/kusura_fidanim.mp3
# 171 Dataset25/MER_Extra25/sad/sarkilara_sordum_soylemediler_emel_sayin.mp3
# 172 Dataset25/MER_Extra25/sad/suzan_suzi_cengiz_ozkan.mp3
# 173 Dataset25/MER_Extra25/sad/sevmekten_kim_usanir_hamiyet_yuceses.mp3
# 174 Dataset25/MER_Extra25/sad/hicaz_keman_taksim.mp3
# 175 Dataset25/MER_Extra25/sad/al_omrumu_cevdet_bagca.mp3
# 176 Dataset25/MER_Extra25/sad/geceler_yarim_oldu_ihsan_mendes.mp3
# 177 Dataset25/MER_Extra25/sad/her_mevsim_icimden_gelip_gecersin_hamiyet_yuceses.mp3
# 178 Dataset25/MER_Extra25/sad/carsambayi_sel_aldi_arslan_akyol.mp3
# 179 Dataset25/MER_Extra25/sad/sarkilar_seni_soyler_zeki_muren.mp3
# 180 Dataset25/MER_Extra25/sad/gullerin_icinden.mp3
# 181 Dataset25/MER_Extra25/sad/unutmamam_seni_zeki_muren.mp3
# 182 Dataset25/MER_Extra25/sad/eledim_eledim_eda_karaytug.mp3
# 183 Dataset25/MER_Extra25/sad/al_yazmalim.mp3
# 184 Dataset25/MER_Extra25/sad/nem_kaldi_gonen_molla.mp3
# 185 Dataset25/MER_Extra25/sad/gulunce_gozlerinin_ici_guluyor_behiye_aksoy.mp3
# 186 Dataset25/MER_Extra25/sad/derdimi_kimlere_desem_rusen_yilmaz.mp3
# 187 Dataset25/MER_Extra25/sad/mihriban_sirri_lacin.mp3
# 188 Dataset25/MER_Extra25/sad/senede_bir_gun_zeki_muren.mp3
# 189 Dataset25/MER_Extra25/sad/ben_yoruldum_hayat_mumin_sarikaya.mp3
# 190 Dataset25/MER_Extra25/sad/cokmu_gordunuz_ebru_gundes.mp3
# 191 Dataset25/MER_Extra25/sad/sevmekten_kim_usanir_muzzeyen_senar.mp3
# 192 Dataset25/MER_Extra25/sad/oy_beni_vurun_vurun_huseyin_ay.mp3
# 193 Dataset25/MER_Extra25/sad/su_kislanin_kapisina_orhan_hakalmaz.mp3
# 194 Dataset25/MER_Extra25/sad/sen_benden_gittin_gideli_erkan_ogur.mp3
# 195 Dataset25/MER_Extra25/sad/vazgectim_ara_dinkjian.mp3
# 196 Dataset25/MER_Extra25/sad/kader_diyemezsin_muazzez_ersoy.mp3
# 197 Dataset25/MER_Extra25/sad/aglama_yar_erkan_ogur.mp3
# 198 Dataset25/MER_Extra25/sad/sen_gelmez_oldun_piyano.mp3
# 199 Dataset25/MER_Extra25/sad/burasi_mustur.mp3
# 200 Dataset25/MER_Extra25/sad/uzun_ince_bir_yoldayim.mp3
# 201 Dataset25/MER_Extra25/angry/bu_sehir_arkandan_gelecek_dizi_muzigi.mp3
# 202 Dataset25/MER_Extra25/angry/yasak_elma_dizi_muzigi.mp3
# 203 Dataset25/MER_Extra25/angry/gunesin_kizlari_dizi_muzigi.mp3
# 204 Dataset25/MER_Extra25/angry/hekimoglu_turkusu.mp3
# 205 Dataset25/MER_Extra25/angry/survivor_ada_konseyi_muzigi.mp3
# 206 Dataset25/MER_Extra25/angry/medcezir_dizi_muzikleri.mp3
# 207 Dataset25/MER_Extra25/angry/hayat_sarkisi_diz_muzikleri2.mp3
# 208 Dataset25/MER_Extra25/angry/elif_dizi_muzigi.mp3
# 209 Dataset25/MER_Extra25/angry/eski_turk_sarkilari.mp3
# 210 Dataset25/MER_Extra25/angry/yazin_oykusu_dizi_muzigi.mp3
# 211 Dataset25/MER_Extra25/angry/kayit_disi_operasyon_dizi_muzikleri1.mp3
# 212 Dataset25/MER_Extra25/angry/eskiya_dunyaya_hukumdar_olmaz_2sezon_dizi_muzigi.mp3
# 213 Dataset25/MER_Extra25/angry/hayat_sarkisi_dizi_muzikleri1.mp3
# 214 Dataset25/MER_Extra25/angry/cendere_kurtlar_vadisi_dizi_muzikleri.mp3
# 215 Dataset25/MER_Extra25/angry/benim_hala_umudum_var_dizi_muzigi.mp3
# 216 Dataset25/MER_Extra25/angry/istanbullu_gelin_dizi_muzikleri.mp3
# 217 Dataset25/MER_Extra25/angry/kayit_disi_operasyon_dizi_muzikleri2.mp3
# 218 Dataset25/MER_Extra25/angry/desti_kpcak_turkleri.mp3
# 219 Dataset25/MER_Extra25/angry/kiraz_mevsimi_2.mp3
# 220 Dataset25/MER_Extra25/angry/isimsizler_dizi_muzikleri2.mp3
# 221 Dataset25/MER_Extra25/angry/cennetin_goz_yaslari_2_dizi_muzigi.mp3
# 222 Dataset25/MER_Extra25/angry/kara_sevda_dizi_muzigi1.mp3
# 223 Dataset25/MER_Extra25/angry/umuda_kelepce_vurulmaz_dizi_muzigi.mp3
# 224 Dataset25/MER_Extra25/angry/insanlik_sucu_dizi_muzikleri2.mp3
# 225 Dataset25/MER_Extra25/angry/isimsizler_dizi_muzikleri3.mp3
# 226 Dataset25/MER_Extra25/angry/isimsizler_dizi_muzikleri1.mp3
# 227 Dataset25/MER_Extra25/angry/dusundurdu_yine_beni_gozlerin_dizi_muzigi.mp3
# 228 Dataset25/MER_Extra25/angry/bir_cocuk_sevdim_dizi_muzigi.mp3
# 229 Dataset25/MER_Extra25/angry/icimdeki_firtina_dizi_muzikleri.mp3
# 230 Dataset25/MER_Extra25/angry/kara_sevda_dizi_muzigi2.mp3
# 231 Dataset25/MER_Extra25/angry/insanlik_sucu_dizi_muzikleri1.mp3
# 232 Dataset25/MER_Extra25/angry/siyah_beyaz_ask_dizi_muzigi.mp3
# 233 Dataset25/MER_Extra25/angry/avlu_dizi_muzikleri.mp3
# 234 Dataset25/MER_Extra25/angry/fatma_gulun_sucu_ne_dizi_muzigi.mp3
# 235 Dataset25/MER_Extra25/angry/cukur_dizi_muzigi2.mp3
# 236 Dataset25/MER_Extra25/angry/kaos_epik_savas_muzikleri.mp3
# 237 Dataset25/MER_Extra25/angry/seviyor_sevmiyor_dizi_muzigi.mp3
# 238 Dataset25/MER_Extra25/angry/arka_sokaklar_dizi_muzigi.mp3
# 239 Dataset25/MER_Extra25/angry/turk_askeri_savas_muzigi.mp3
# 240 Dataset25/MER_Extra25/angry/karagul_dizi_muzikleri.mp3
# 241 Dataset25/MER_Extra25/angry/yeter_dizi_muzigi.mp3
# 242 Dataset25/MER_Extra25/angry/adanli2.mp3
# 243 Dataset25/MER_Extra25/angry/ucurum_gerilim_alp_yenier.mp3
# 244 Dataset25/MER_Extra25/angry/sahsiyet_dizi_muzigi.mp3
# 245 Dataset25/MER_Extra25/angry/coban_yildizi_dizi_muzigi.mp3
# 246 Dataset25/MER_Extra25/angry/eskiya_dunyaya_hukumdar_olmaz_3sezon_dizi_muzigi.mp3
# 247 Dataset25/MER_Extra25/angry/ezel_dizi_muzigi2.mp3
# 248 Dataset25/MER_Extra25/angry/kalp_atisi.mp3
# 249 Dataset25/MER_Extra25/angry/adanali.mp3
# 250 Dataset25/MER_Extra25/angry/bir-zamanlar-cukur-ova-part.mp3
# 251 Dataset25/MER_Extra25/angry/fazilet_hanim_ve_kizlari_dizi_muzigi.mp3
# 252 Dataset25/MER_Extra25/angry/yuvamdaki_dusman_dizi_muzikleri.mp3
# 253 Dataset25/MER_Extra25/angry/hickirik_dizi_muzikleri.mp3
# 254 Dataset25/MER_Extra25/angry/ask_ve_mavi_dizi_muzigi.mp3
# 255 Dataset25/MER_Extra25/angry/erkenci-kus-dizi-muzigi-part.mp3
# 256 Dataset25/MER_Extra25/angry/tatar_gelin_dizi_muzikleri.mp3
# 257 Dataset25/MER_Extra25/angry/bir-litre-goz-yasi-part.mp3
# 258 Dataset25/MER_Extra25/angry/sana_bir_sir_verecegim_dizi_muzigi.mp3
# 259 Dataset25/MER_Extra25/angry/meryem_dizi_muzikleri2.mp3
# 260 Dataset25/MER_Extra25/angry/medcezir_dizi_muzikleri2.mp3
# 261 Dataset25/MER_Extra25/angry/kehribar_dizi_muzikleri.mp3
# 262 Dataset25/MER_Extra25/angry/doluna_dizi_muzigi.mp3
# 263 Dataset25/MER_Extra25/angry/soz_dizi_muzigi_3.mp3
# 264 Dataset25/MER_Extra25/angry/cukur_dizi_muzigi.mp3
# 265 Dataset25/MER_Extra25/angry/sen_anlat_karadeniz_dizi_muzigi.mp3
# 266 Dataset25/MER_Extra25/angry/beyaz_yalan_dizi_muzigi.mp3
# 267 Dataset25/MER_Extra25/angry/gullerin_savasi_dizi_muzigi.mp3
# 268 Dataset25/MER_Extra25/angry/filinta_dizi_muzigi1.mp3
# 269 Dataset25/MER_Extra25/angry/soz_dizi_muzigi_1.mp3
# 270 Dataset25/MER_Extra25/angry/eski_hikaye_dizi_muzigi.mp3
# 271 Dataset25/MER_Extra25/angry/meryem_dizi_muzikleri1.mp3
# 272 Dataset25/MER_Extra25/angry/dilan_hanim_dizi_muzigi.mp3
# 273 Dataset25/MER_Extra25/angry/kurtulus_filim_muzikleri.mp3
# 274 Dataset25/MER_Extra25/angry/kiraz_mevsimi_dizi_muzikleri.mp3
# 275 Dataset25/MER_Extra25/angry/yuvamdaki_dusman_dizi_muzikleri2.mp3
# 276 Dataset25/MER_Extra25/angry/yeni_ceri_marsi.mp3
# 277 Dataset25/MER_Extra25/angry/adini_Feriha_koydum.mp3
# 278 Dataset25/MER_Extra25/angry/gunesi_beklerken_dizi_muzigi.mp3
# 279 Dataset25/MER_Extra25/angry/arka_sokaklar_dizi_muzigi2.mp3
# 280 Dataset25/MER_Extra25/angry/not_defteri_dizi_muzikleri.mp3
# 281 Dataset25/MER_Extra25/angry/yer_gok_ask_dizi_muzikleri.mp3
# 282 Dataset25/MER_Extra25/angry/tatli_intikan_dizi_muzigi.mp3
# 283 Dataset25/MER_Extra25/angry/bugunun_saraylisi_dizi_mugizi.mp3
# 284 Dataset25/MER_Extra25/angry/ufak_tefek_cinayetler_dizi_muzigi.mp3
# 285 Dataset25/MER_Extra25/angry/genis_aile_dizi_muzigi.mp3
# 286 Dataset25/MER_Extra25/angry/osmanli_savas_marsi1.mp3
# 287 Dataset25/MER_Extra25/angry/kacak_dizi_muzikleri1.mp3
# 288 Dataset25/MER_Extra25/angry/ay_yildiz_tim_savas_muzigi.mp3
# 289 Dataset25/MER_Extra25/angry/cennetin_goz_yaslari_1_dizi_muzigi.mp3
# 290 Dataset25/MER_Extra25/angry/aksiyon_gerilim.mp3
# 291 Dataset25/MER_Extra25/angry/cilek_kokusu_dizi_muzigi.mp3
# 292 Dataset25/MER_Extra25/angry/canakkale_yolun_sonu_dizi_muzikleri.mp3
# 293 Dataset25/MER_Extra25/angry/cemberin_icinde_dizi_muzigi.mp3
# 294 Dataset25/MER_Extra25/angry/eskiya_dunyaya_hukumdar_olmaz_3_dizi_muzikleri.mp3
# 295 Dataset25/MER_Extra25/angry/dorduncu_murat_muzikleri.mp3
# 296 Dataset25/MER_Extra25/angry/araf_zaman_dizi_muzigi.mp3
# 297 Dataset25/MER_Extra25/angry/kacak_dizi_muzikleri2.mp3
# 298 Dataset25/MER_Extra25/angry/sungurlar_dizi_muzigi.mp3
# 299 Dataset25/MER_Extra25/angry/savasci_dizi_muzigi1.mp3
# 300 Dataset25/MER_Extra25/angry/turk_savas_muzigi1.mp3
# 301 Dataset25/MER_Extra25/relaxed/ben-yoruldum-hayat-part-cinar-cetinkaya-part.mp3
# 302 Dataset25/MER_Extra25/relaxed/julide_ozcelik_yalan_dunya.mp3
# 303 Dataset25/MER_Extra25/relaxed/fikret_kizilok_farketmeden.mp3
# 304 Dataset25/MER_Extra25/relaxed/serta_erener_tesaduf_ask.mp3
# 305 Dataset25/MER_Extra25/relaxed/mehmet_gureli_kimse_bilmez.mp3
# 306 Dataset25/MER_Extra25/relaxed/fikret_kizilok_basbasa.mp3
# 307 Dataset25/MER_Extra25/relaxed/bulent_ortacgil_yuzunu_dokme_kucuk_kiz.mp3
# 308 Dataset25/MER_Extra25/relaxed/julide_ozcelik_zaman.mp3
# 309 Dataset25/MER_Extra25/relaxed/fikret_kizilok_gonul.mp3
# 310 Dataset25/MER_Extra25/relaxed/kelebek_cigdem_Erkan.mp3
# 311 Dataset25/MER_Extra25/relaxed/berguzar_korel_kaybolan_yillar.mp3
# 312 Dataset25/MER_Extra25/relaxed/cigdem_erken_cakmak.mp3
# 313 Dataset25/MER_Extra25/relaxed/duman_elleri_ellerime.mp3
# 314 Dataset25/MER_Extra25/relaxed/demir_demirkan_doldur_kadehleri.mp3
# 315 Dataset25/MER_Extra25/relaxed/birsen_tezer_seher_vahti.mp3
# 316 Dataset25/MER_Extra25/relaxed/bulent_ortacgil_sana_geldim.mp3
# 317 Dataset25/MER_Extra25/relaxed/birsen_tezer_sarkicinin_sarkicisi.mp3
# 318 Dataset25/MER_Extra25/relaxed/nev_kimseye_etmem_sikayet.mp3
# 319 Dataset25/MER_Extra25/relaxed/onur_yardimci_bana_donme.mp3
# 320 Dataset25/MER_Extra25/relaxed/mor_ve_otesi_bisiklet.mp3
# 321 Dataset25/MER_Extra25/relaxed/ozdemir_erdogan_ac_kapiyi_gir_iceri.mp3
# 322 Dataset25/MER_Extra25/relaxed/ajda-pekkan-ya-sonra- Part.mp3
# 323 Dataset25/MER_Extra25/relaxed/bulent_ortacgil_sensiz_olmaz.mp3
# 324 Dataset25/MER_Extra25/relaxed/cigdem_erken_laleler.mp3
# 325 Dataset25/MER_Extra25/relaxed/vedat_sakman_usluca.mp3
# 326 Dataset25/MER_Extra25/relaxed/ayten_alpman_erkekler_aglamaz.mp3
# 327 Dataset25/MER_Extra25/relaxed/nilufer_ayrilik_hasreti.mp3
# 328 Dataset25/MER_Extra25/relaxed/ozan_musluoglu_kimse_duymasin.mp3
# 329 Dataset25/MER_Extra25/relaxed/nukhet_ruacan_her_sey_sevgiyle_baslar.mp3
# 330 Dataset25/MER_Extra25/relaxed/birsen_tezer_ciglik_cigliga.mp3
# 331 Dataset25/MER_Extra25/relaxed/ezgini_gunlugu_mutlu_son.mp3
# 332 Dataset25/MER_Extra25/relaxed/kimse_bilmez_kursat_basar.mp3
# 333 Dataset25/MER_Extra25/relaxed/ben_varim_kursat.mp3
# 334 Dataset25/MER_Extra25/relaxed/yalin_keske.mp3
# 335 Dataset25/MER_Extra25/relaxed/sene_sener_bak_bana.mp3
# 336 Dataset25/MER_Extra25/relaxed/julide_ozcelik_esitiz_eninde_sonunda.mp3
# 337 Dataset25/MER_Extra25/relaxed/pilli_bebek_cogu_zaman.mp3
# 338 Dataset25/MER_Extra25/relaxed/kimseye_etmem_sikayet.mp3
# 339 Dataset25/MER_Extra25/relaxed/bana_ellerini_ver_ozdemir_erdogan.mp3
# 340 Dataset25/MER_Extra25/relaxed/kendinle_kalirsin_julide_ozcelik.mp3
# 341 Dataset25/MER_Extra25/relaxed/mustafa_ceceli_elvan_gunaydin.mp3
# 342 Dataset25/MER_Extra25/relaxed/bulent_ortacgil_yagmur.mp3
# 343 Dataset25/MER_Extra25/relaxed/enbe_orkestrasi_hikaye.mp3
# 344 Dataset25/MER_Extra25/relaxed/mazi_kalbimde_bir_yaradir_dilek_turkan.mp3
# 345 Dataset25/MER_Extra25/relaxed/uyanma_uyu_selim_gungoren.mp3
# 346 Dataset25/MER_Extra25/relaxed/nim_sofyan_senden_bana_yar_olmaz.mp3
# 347 Dataset25/MER_Extra25/relaxed/sevince_erkin_koray.mp3
# 348 Dataset25/MER_Extra25/relaxed/eren_cilgin_mavi_yalan.mp3
# 349 Dataset25/MER_Extra25/relaxed/birsen_tezer_di_gel_yanima.mp3
# 350 Dataset25/MER_Extra25/relaxed/Birsen_tezer_istanbul.mp3
# 351 Dataset25/MER_Extra25/relaxed/fikret_kizilok_guzel_ne_guzel_olmussun.mp3
# 352 Dataset25/MER_Extra25/relaxed/julide_ozcelik_kimse_bilmez.mp3
# 353 Dataset25/MER_Extra25/relaxed/dusundukce_selen_gulun.mp3
# 354 Dataset25/MER_Extra25/relaxed/mabel_matis_supheli_sarkinin_sairi.mp3
# 355 Dataset25/MER_Extra25/relaxed/mfo_bodrum_bodrum.mp3
# 356 Dataset25/MER_Extra25/relaxed/cem_ozkan_don_bana.mp3
# 357 Dataset25/MER_Extra25/relaxed/sinan_kaynakci_kendine_zaman_ver.mp3
# 358 Dataset25/MER_Extra25/relaxed/zeynep_dizdar_vazgec_gonul.mp3
# 359 Dataset25/MER_Extra25/relaxed/sertap_erener_acik_adres.mp3
# 360 Dataset25/MER_Extra25/relaxed/birsen-tezer-bilsen-part.mp3
# 361 Dataset25/MER_Extra25/relaxed/sumru_agir_yuruyen_issiz.mp3
# 362 Dataset25/MER_Extra25/relaxed/aklim_hep_sende.mp3
# 363 Dataset25/MER_Extra25/relaxed/aysegul_aldinc_kucuk_seyler.mp3
# 364 Dataset25/MER_Extra25/relaxed/fikrimin-ince-gulu-tamer-zeytinoglu-part.mp3
# 365 Dataset25/MER_Extra25/relaxed/mert_royfe_zaman.mp3
# 366 Dataset25/MER_Extra25/relaxed/julide_ozcelik_kara_toprak.mp3
# 367 Dataset25/MER_Extra25/relaxed/sertap_erener_bahcede.mp3
# 368 Dataset25/MER_Extra25/relaxed/selim_gulgoren_uyanma_uyu.mp3
# 369 Dataset25/MER_Extra25/relaxed/mahsar_alanson_benim_hala_umudum_var.mp3
# 370 Dataset25/MER_Extra25/relaxed/fikret_kizilok_gecenin_ucunde.mp3
# 371 Dataset25/MER_Extra25/relaxed/tel_tel_taradim_nurten_demirkol.mp3
# 372 Dataset25/MER_Extra25/relaxed/kirac_kalbin_tek_arkadasi.mp3
# 373 Dataset25/MER_Extra25/relaxed/sumru_agir_yuruyen_terk_edilmis_kent.mp3
# 374 Dataset25/MER_Extra25/relaxed/ozdemir-erdogan-baharda-kuslar-gibi-part.mp3
# 375 Dataset25/MER_Extra25/relaxed/sebnem_ferah_yagmurlar.mp3
# 376 Dataset25/MER_Extra25/relaxed/fikret_kizilok_bosuna.mp3
# 377 Dataset25/MER_Extra25/relaxed/erol_evgin_bir_ilk_bahar_sabahi.mp3
# 378 Dataset25/MER_Extra25/relaxed/feridun_duzagac_sevgi.mp3
# 379 Dataset25/MER_Extra25/relaxed/yine_yazi_bekleriz_tnk.mp3
# 380 Dataset25/MER_Extra25/relaxed/zeynep_dizdar_bir_cocuk_sevdim.mp3
# 381 Dataset25/MER_Extra25/relaxed/julide_ozcelik_siradan_bir_gun.mp3
# 382 Dataset25/MER_Extra25/relaxed/alp_ersonmez_burada_yarali_biri_var.mp3
# 383 Dataset25/MER_Extra25/relaxed/fikret_kizilok_gidiyorsun.mp3
# 384 Dataset25/MER_Extra25/relaxed/julide_ozcelik_bugun_neden_gelmedin.mp3
# 385 Dataset25/MER_Extra25/relaxed/sigaramin-dumani-tamer-zeytinoglu-part.mp3
# 386 Dataset25/MER_Extra25/relaxed/fikret_kizilok_ben_gidersem.mp3
# 387 Dataset25/MER_Extra25/relaxed/ezginin_gunlugu_kiyisiz_deniz.mp3
# 388 Dataset25/MER_Extra25/relaxed/tanju_duru_aklim_hep_sende.mp3
# 389 Dataset25/MER_Extra25/relaxed/teoman_senden_once_senden_sonra.mp3
# 390 Dataset25/MER_Extra25/relaxed/elvan_gunaydin.mp3
# 391 Dataset25/MER_Extra25/relaxed/ezginin_gunlugu_ask_yuzunden.mp3
# 392 Dataset25/MER_Extra25/relaxed/roya_gemiciler.mp3
# 393 Dataset25/MER_Extra25/relaxed/basak_yavuz_gidersen.mp3
# 394 Dataset25/MER_Extra25/relaxed/tnk_yine_yazi_bekleriz.mp3
# 395 Dataset25/MER_Extra25/relaxed/sevinc_tevz_ve_ben_yalniz.mp3
# 396 Dataset25/MER_Extra25/relaxed/sumru_agir_yuruyen_guz_defteri.mp3
# 397 Dataset25/MER_Extra25/relaxed/onur_mete_bu_asktan_gidiyorum.mp3
# 398 Dataset25/MER_Extra25/relaxed/demir_demircan_aci_nefes.mp3
# 399 Dataset25/MER_Extra25/relaxed/yalin_ki_sen.mp3
# 400 Dataset25/MER_Extra25/relaxed/sarp_madem_ortadaki_gecit.mp3

# %%
duration_extra25 = []
for i in range(len(file_dir25_extra)):
    y,sr = librosa.load(file_dir25_extra[i])
    d = librosa.get_duration(y=y,sr=sr)
    duration_extra25.append(d)

# %%
# Check duration again
for i in range(len(duration_extra25)):
    if duration_extra25[i]!=25.5:
        print(i,duration_extra25[i])

# %% [markdown]
# ## 3. Feature Extraction
# ### 3.1. Turn features into 1D feature vector

# %%
librosa.key_to_notes(key='C:maj')
# Out:
# ['C', 'C♯', 'D', 'D♯', 'E', 'F', 'F♯', 'G', 'G♯', 'A', 'A♯', 'B']

# %%
import re
def key_scale_finder(file):
    pitches = ['C','C#','D','D#','E','F','F#','G','G#','A','A#','B']
    y,sr = librosa.load(file)
    key = librosa.feature.chroma_stft(y=y,sr=sr).sum(axis=1).argmax()
    if re.search("\#$",pitches[key]):
        scale = "minor"
    else:
        scale = "major"
    return scale,pitches[key]

# %%
def feature_1d(file):
    try:
        y,sr = librosa.load(file)
    except:
        print('No such file')
        quit()
    
    f = [] 
    
    # tempo
    tempo = librosa.beat.tempo(y=y,sr=sr)[0]
    f.append(tempo)  
    
    # RMS
    #S, phase = librosa.magphase(librosa.stft(y))
    rms = librosa.feature.rms(y=y)
    rms_mean = np.mean(rms)
    rms_var = np.var(rms)
    f.append(rms_mean)
    f.append(rms_var)
    
    # chroma features
    chroma = librosa.feature.chroma_stft(y=y,sr=sr)
    chroma_mean = np.mean(chroma)
    chroma_var = np.var(chroma)
    f.append(chroma_mean)
    f.append(chroma_var)
    
    # spectral centroid
    centroid = librosa.feature.spectral_centroid(y=y)
    centroid_mean = np.mean(centroid)
    centroid_var = np.var(centroid)
    f.append(centroid_mean)
    f.append(centroid_var)
    
    # spectral rolloff
    rolloff = librosa.feature.spectral_rolloff(y=y+0.01, sr=sr)
    rolloff_mean = np.mean(rolloff)
    rolloff_var = np.var(rolloff)
    f.append(rolloff_mean)
    f.append(rolloff_var)
    
    # zero crossing rate
    zcr = librosa.feature.zero_crossing_rate(y=y)
    zcr_mean = np.mean(zcr)
    zcr_var = np.var(zcr)
    f.append(zcr_mean)
    f.append(zcr_var)
    
    # tonnetz
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    tonnetz_mean = np.mean(tonnetz)
    tonnetz_var  = np.var(tonnetz)
    f.append(tonnetz_mean)
    f.append(tonnetz_var)
    
    #mel
    s = librosa.feature.melspectrogram(y=y, sr=sr)
    mel = librosa.amplitude_to_db(s, ref=np.max)
    mel_mean = np.mean(mel)
    mel_var = np.var(mel)
    f.append(mel_mean)
    f.append(mel_var)
    
    #mfcc
    mfcc = librosa.feature.mfcc(y=y,sr=sr,n_mfcc=20)
    m = len(mfcc)
    mfcc_mean = np.zeros((m,))
    mfcc_var = np.zeros((m,))
    for i in range(len(mfcc)):
        mfcc_mean[i] = np.mean(mfcc[i])
        mfcc_var[i]= np.var(mfcc[i])
        f.append(mfcc_mean[i])
        f.append(mfcc_var[i])
    
    return np.array(f)

# %%
#Extract Key and Scale
key1 = []
scale1 = []
for i in range(len(file_dir25)):
    key1.append(key_scale_finder(file_dir25[i])[1])
    scale1.append(key_scale_finder(file_dir25[i])[0])

# %%
features1 = np.zeros((898,55))
for i in range(0,898):
    features1[i] = feature_1d(file_dir25[i])
features1.shape
# Out:
# (898, 53)

# %%
# Create a data frame to store all the data
feature1 = pd.DataFrame()

# %%
# Store 15 features to data frame
col_name = ['tempo','rms_mean','rms_var','chroma_mean','chroma_var',
            'centroid_mean','centroid_var','rolloff_mean','roll_off_var',
            'zcr_mean','zcr_var','tonnetz_mean', 'tonnetz_var', 'mel_mean', 'mel_var']
# Store 20 mfccs mean and var to data frame
mfccs_col_name = []
for i in range(0,20):
    mfccs_col_name.append("mfcc_mean_"+str(i+1))
    mfccs_col_name.append("mfcc_var_"+str(i+1))

# %%
# Label the mood
mood1 = []
for i in range(len(file_dir25)):
    m = os.path.basename(os.path.dirname(filewithdir[i]))
    mood1.append(m)

# %%
# Store file name
feature1['file'] = file_dir25
# Store key and scale
feature1['scale'] = scale1
feature1['key'] = key1
# Store 13 features and 20 mfccs
for i in range(len(col_name)):
    feature1[col_name[i]] = features1[:,i]
for i in range(len(mfccs_col_name)):
    feature1[mfccs_col_name[i]] = features1[:,i+15]
# Store mood
feature1['mood'] = mood1

# %%
# Rename the mood classes
for i in range(len(feature1['mood'])):
    if feature1['mood'][i] == "Q1":
        feature1['mood'][i] = "happy"
    
    elif feature1['mood'][i] == "Q2":
        feature1['mood'][i] = "angry"
    
    elif feature1['mood'][i] == "Q3":
        feature1['mood'][i] = "sad"
    
    elif feature1['mood'][i] == "Q4":
        feature1['mood'][i] = "relaxed"

# %%
# Create the Excel file
pd.ExcelWriter('Features1D/Features/Features.xlsx')

# %%
# Store the Feature into excel file
feature1.to_excel('Features1D/Features/Features.xlsx')

# %%
key2= []
scale2 = []
for i in range(len(file_dir25_extra)):
    key2.append(key_scale_finder(file_dir25_extra[i])[1])
    scale2.append(key_scale_finder(file_dir25_extra[i])[0])

# %%
features2 = np.zeros((400,53))
for i in range(0,400):
    features2[i] = feature_1d(file_dir25_extra[i])
# Out:
# /var/folders/hp/2dbkkkm52hsd14c13kbw0vr00000gp/T/ipykernel_44273/718064517.py:11: FutureWarning: librosa.beat.tempo
# 	This function was moved to 'librosa.feature.rhythm.tempo' in librosa version 0.10.0.
# 	This alias will be removed in librosa version 1.0.
#   tempo = librosa.beat.tempo(y=y,sr=sr)[0]

# %%
# Create a data frame to store all the data
feature2 = pd.DataFrame()

# %%
feature2['file'] = file_dir25_extra
feature2['scale'] = scale2
feature2['key'] = key2
for i in range(len(col_name)):
    feature2[col_name[i]] = features2[:,i]
for i in range(len(mfccs_col_name)):
    feature2[mfccs_col_name[i]] = features2[:,i+13]
# Store mood
feature2['mood'] = mood2

# %%
# Create the Excel file
pd.ExcelWriter('Features1D/Features/Features_extra.xlsx')

# %%
# Store the Feature into excel file
feature2.to_excel('Features1D/Features/Features_extra.xlsx')
